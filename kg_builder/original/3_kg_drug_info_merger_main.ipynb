# %% [markdown]
# Merge all fetched datasets originating from Monarch Initiative, TTD and DrugCentral.
#
# Adapted by Rosa Zwart from Jupyter Notebook found at https://github.com/PPerdomoQ/rare-disease-explainer/blob/main/3_Predictions_and_explanations.ipynb

# %%
import os
import sys
import pandas as pd
import numpy as np

current_dir = os.getcwd()
project_root = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(project_root)

import util.constants as constants

# %%
DISEASE_PREFIX = 'dmd'

# %% [markdown]
# #### **Format TTD data**

# %% [markdown]
# Save a list of all associations between DRUG and GENE in a csv file.

# %%
drug_targets = pd.read_csv(f'output/matched_drug_targets_{DISEASE_PREFIX}.csv')
drug_targets
# Out:
#                DRUG_NAME  STRUCT_ID  \
# 0       (S)-nitrendipine          6
# 1       (S)-nitrendipine          6
# 2       (S)-nitrendipine          6
# 3    phenylbutanoic acid         24
# 4          acetylcholine         65
# ..                   ...        ...
# 386         infigratinib       5459
# 387         infigratinib       5459
# 388         infigratinib       5459
# 389         infigratinib       5459
# 390         infigratinib       5459
#
#                                            TARGET_NAME TARGET_CLASS ACCESSION  \
# 0    Voltage-dependent L-type calcium channel subun...  Ion channel    Q01668
# 1    Voltage-dependent L-type calcium channel subun...  Ion channel    O60840
# 2    Voltage-dependent L-type calcium channel subun...  Ion channel    Q13936
# 3                                Histone deacetylase 2       Enzyme    Q92769
# 4                 Muscarinic acetylcholine receptor M1         GPCR    P11229
# ..                                                 ...          ...       ...
# 386         Proto-oncogene tyrosine-protein kinase Src       Kinase    P12931
# 387                        Tyrosine-protein kinase Lyn       Kinase    P07948
# 388         Proto-oncogene tyrosine-protein kinase Src       Kinase    P12931
# 389                        Tyrosine-protein kinase Lyn       Kinase    P07948
# 390         Proto-oncogene tyrosine-protein kinase Src       Kinase    P12931
#
#         GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ...  \
# 0    CACNA1D  CAC1D_HUMAN       8.40       NaN     IC50  ...
# 1    CACNA1F  CAC1F_HUMAN       6.00       NaN     IC50  ...
# 2    CACNA1C  CAC1C_HUMAN        NaN       NaN      NaN  ...
# 3      HDAC2  HDAC2_HUMAN       4.19       NaN     IC50  ...
# 4      CHRM1   ACM1_HUMAN       6.11       NaN     EC50  ...
# ..       ...          ...        ...       ...      ...  ...
# 386      SRC    SRC_HUMAN       5.53       NaN     IC50  ...
# 387      LYN    LYN_HUMAN       6.52       NaN     IC50  ...
# 388      SRC    SRC_HUMAN       5.53       NaN     IC50  ...
# 389      LYN    LYN_HUMAN       6.52       NaN     IC50  ...
# 390      SRC    SRC_HUMAN       5.53       NaN     IC50  ...
#
#                 ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# 0                   IUPHAR        =  1.0                 IUPHAR
# 1                   IUPHAR        ~  NaN                    NaN
# 2    SCIENTIFIC LITERATURE      NaN  1.0  SCIENTIFIC LITERATURE
# 3                   CHEMBL        =  NaN                    NaN
# 4                   CHEMBL        =  NaN                    NaN
# ..                     ...      ...  ...                    ...
# 386                 CHEMBL        =  NaN                    NaN
# 387                 CHEMBL        =  NaN                    NaN
# 388                 CHEMBL        =  NaN                    NaN
# 389                 CHEMBL        =  NaN                    NaN
# 390                 CHEMBL        =  NaN                    NaN
#
#     ACT_SOURCE_URL                                     MOA_SOURCE_URL  \
# 0              NaN  https://www.ebi.ac.uk/chembl/compound/inspect/...
# 1              NaN                                                NaN
# 2              NaN           https://pubmed.ncbi.nlm.nih.gov/17276408
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ..             ...                                                ...
# 386            NaN                                                NaN
# 387            NaN                                                NaN
# 388            NaN                                                NaN
# 389            NaN                                                NaN
# 390            NaN                                                NaN
#
#           ACTION_TYPE    TDL      ORGANISM      NEW_ID
# 0    GATING INHIBITOR  Tclin  Homo sapiens   HGNC:1391
# 1    GATING INHIBITOR  Tclin  Homo sapiens   HGNC:1393
# 2             BLOCKER  Tclin  Homo sapiens   HGNC:1390
# 3                 NaN  Tclin  Homo sapiens   HGNC:4853
# 4                 NaN  Tclin  Homo sapiens   HGNC:1950
# ..                ...    ...           ...         ...
# 386               NaN  Tclin  Homo sapiens  HGNC:11283
# 387               NaN  Tclin  Homo sapiens   HGNC:6735
# 388               NaN  Tclin  Homo sapiens  HGNC:11283
# 389               NaN  Tclin  Homo sapiens   HGNC:6735
# 390               NaN  Tclin  Homo sapiens  HGNC:11283
#
# [391 rows x 21 columns]

# %% [markdown]
# Get columns that are relevant.

# %%
drug_targets_values = drug_targets.copy()[['STRUCT_ID', 'DRUG_NAME', 'NEW_ID']]
drug_targets_values
# Out:
#      STRUCT_ID            DRUG_NAME      NEW_ID
# 0            6     (S)-nitrendipine   HGNC:1391
# 1            6     (S)-nitrendipine   HGNC:1393
# 2            6     (S)-nitrendipine   HGNC:1390
# 3           24  phenylbutanoic acid   HGNC:4853
# 4           65        acetylcholine   HGNC:1950
# ..         ...                  ...         ...
# 386       5459         infigratinib  HGNC:11283
# 387       5459         infigratinib   HGNC:6735
# 388       5459         infigratinib  HGNC:11283
# 389       5459         infigratinib   HGNC:6735
# 390       5459         infigratinib  HGNC:11283
#
# [391 rows x 3 columns]

# %%
drug_targets_values.drop_duplicates(inplace=True)
drug_targets_values.shape[0]
# Out:
# 380

# %% [markdown]
# Add new columns that are needed to be included in the dataframe.

# %%
dict_list = []

for i, row in drug_targets_values.iterrows():
    tuple_dict = {
        'id': f'TTD{i}',
        'subject_id': str(row['STRUCT_ID']),
        'subject_label': row['DRUG_NAME'],
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['NEW_ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:TTD',
        'relation_label': 'targets',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugtarget_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugtarget_associations_df
# Out:
#          id subject_id        subject_label  subject_iri subject_category  \
# 0      TTD0          6     (S)-nitrendipine          NaN             DRUG
# 1      TTD1          6     (S)-nitrendipine          NaN             DRUG
# 2      TTD2          6     (S)-nitrendipine          NaN             DRUG
# 3      TTD3         24  phenylbutanoic acid          NaN             DRUG
# 4      TTD4         65        acetylcholine          NaN             DRUG
# ..      ...        ...                  ...          ...              ...
# 375  TTD381       5431         tirbanibulin          NaN             DRUG
# 376  TTD382       5431         tirbanibulin          NaN             DRUG
# 377  TTD385       5443           casimersen          NaN             DRUG
# 378  TTD386       5459         infigratinib          NaN             DRUG
# 379  TTD387       5459         infigratinib          NaN             DRUG
#
#      subject_taxon_id  subject_taxon_label   object_id  object_label  \
# 0                 NaN                  NaN   HGNC:1391           NaN
# 1                 NaN                  NaN   HGNC:1393           NaN
# 2                 NaN                  NaN   HGNC:1390           NaN
# 3                 NaN                  NaN   HGNC:4853           NaN
# 4                 NaN                  NaN   HGNC:1950           NaN
# ..                ...                  ...         ...           ...
# 375               NaN                  NaN  HGNC:11283           NaN
# 376               NaN                  NaN   HGNC:6735           NaN
# 377               NaN                  NaN   HGNC:2928           NaN
# 378               NaN                  NaN  HGNC:11283           NaN
# 379               NaN                  NaN   HGNC:6735           NaN
#
#      object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0           NaN              NaN              NaN                 NaN
# 1           NaN              NaN              NaN                 NaN
# 2           NaN              NaN              NaN                 NaN
# 3           NaN              NaN              NaN                 NaN
# 4           NaN              NaN              NaN                 NaN
# ..          ...              ...              ...                 ...
# 375         NaN              NaN              NaN                 NaN
# 376         NaN              NaN              NaN                 NaN
# 377         NaN              NaN              NaN                 NaN
# 378         NaN              NaN              NaN                 NaN
# 379         NaN              NaN              NaN                 NaN
#
#       relation_id relation_label  relation_iri
# 0    CustomRO:TTD        targets           NaN
# 1    CustomRO:TTD        targets           NaN
# 2    CustomRO:TTD        targets           NaN
# 3    CustomRO:TTD        targets           NaN
# 4    CustomRO:TTD        targets           NaN
# ..            ...            ...           ...
# 375  CustomRO:TTD        targets           NaN
# 376  CustomRO:TTD        targets           NaN
# 377  CustomRO:TTD        targets           NaN
# 378  CustomRO:TTD        targets           NaN
# 379  CustomRO:TTD        targets           NaN
#
# [380 rows x 16 columns]

# %%
drugtarget_associations_df.to_csv(f'../../{constants.OUTPUT_FOLDER}/{DISEASE_PREFIX}/prev_{DISEASE_PREFIX}_ttd_associations.csv', index=None)

# %% [markdown]
# #### **Format DrugCentral data**

# %%
drug_diseases = pd.read_csv(f'output/matched_drug_to_disease_{DISEASE_PREFIX}.csv')
drug_diseases
# Out:
#     Unnamed: 0  DRUG_ID         DRUG_NAME  \
# 0          975     4483       Carfilzomib
# 1         2136     1043        Ergotamine
# 2         2168      812       Desipramine
# 3         2389     4225          Axitinib
# 4         2632     4175       Linagliptin
# ..         ...      ...               ...
# 68       25482      313        Diphenidol
# 69       25591     1142        Felodipine
# 70       26312     2630  Thiethylperazine
# 71       27057      318     Benzbromarone
# 72       27209     1511        Isradipine
#
#                                      DISEASES       PHASE  \
# 0                     Small-cell lung cancer    Phase 1/2
# 1                                   Headache     Approved
# 2   Attention deficit hyperactivity disorder     Approved
# 3                       Renal cell carcinoma     Approved
# 4                            Type-2 diabetes     Approved
# ..                                        ...         ...
# 68                                    Nausea     Approved
# 69                              Hypertension     Approved
# 70                                    Nausea     Approved
# 71                                      Gout     Approved
# 72                              Hypertension     Approved
#
#                                         Name  \
# 0                     small cell lung cancer
# 1                                   headache
# 2   attention deficit hyperactivity disorder
# 3                       renal cell carcinoma
# 4                            type 2 diabetes
# ..                                       ...
# 68                                    nausea
# 69                              hypertension
# 70                                    nausea
# 71                                      gout
# 72                              hypertension
#
#                             ontologyTermName  \
# 0                  Small cell lung carcinoma
# 1                                   Headache
# 2   Attention deficit hyperactivity disorder
# 3                       Renal cell carcinoma
# 4                  Type II diabetes mellitus
# ..                                       ...
# 68                                    Nausea
# 69                              Hypertension
# 70                                    Nausea
# 71                                      Gout
# 72                              Hypertension
#
#                               ontologyTermIRI  validated  review          ID
# 0   http://purl.obolibrary.org/obo/HP_0030357      False   False  HP:0030357
# 1   http://purl.obolibrary.org/obo/HP_0002315      False   False  HP:0002315
# 2   http://purl.obolibrary.org/obo/HP_0007018      False   False  HP:0007018
# 3   http://purl.obolibrary.org/obo/HP_0005584      False   False  HP:0005584
# 4   http://purl.obolibrary.org/obo/HP_0005978      False   False  HP:0005978
# ..                                        ...        ...     ...         ...
# 68  http://purl.obolibrary.org/obo/HP_0002018      False   False  HP:0002018
# 69  http://purl.obolibrary.org/obo/HP_0000822      False   False  HP:0000822
# 70  http://purl.obolibrary.org/obo/HP_0002018      False   False  HP:0002018
# 71  http://purl.obolibrary.org/obo/HP_0001997      False   False  HP:0001997
# 72  http://purl.obolibrary.org/obo/HP_0000822      False   False  HP:0000822
#
# [73 rows x 11 columns]

# %%
drug_diseases_values = drug_diseases.copy()[['DRUG_ID', 'ID']]
drug_diseases_values
# Out:
#     DRUG_ID          ID
# 0      4483  HP:0030357
# 1      1043  HP:0002315
# 2       812  HP:0007018
# 3      4225  HP:0005584
# 4      4175  HP:0005978
# ..      ...         ...
# 68      313  HP:0002018
# 69     1142  HP:0000822
# 70     2630  HP:0002018
# 71      318  HP:0001997
# 72     1511  HP:0000822
#
# [73 rows x 2 columns]

# %%
dict_list = []

for i, row in drug_diseases_values.iterrows():
    tuple_dict = {
        'id': f'DC{i}',
        'subject_id': row['DRUG_ID'],
        'subject_label': np.nan,
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:DC',
        'relation_label': 'is substance that treats',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugdiseases_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugdiseases_associations_df.head(10)
# Out:
#     id  subject_id  subject_label  subject_iri subject_category  \
# 0  DC0        4483            NaN          NaN             DRUG
# 1  DC1        1043            NaN          NaN             DRUG
# 2  DC2         812            NaN          NaN             DRUG
# 3  DC3        4225            NaN          NaN             DRUG
# 4  DC4        4175            NaN          NaN             DRUG
# 5  DC5        4175            NaN          NaN             DRUG
# 6  DC6        5431            NaN          NaN             DRUG
# 7  DC7        1683            NaN          NaN             DRUG
# 8  DC8        4175            NaN          NaN             DRUG
# 9  DC9        4175            NaN          NaN             DRUG
#
#    subject_taxon_id  subject_taxon_label   object_id  object_label  \
# 0               NaN                  NaN  HP:0030357           NaN
# 1               NaN                  NaN  HP:0002315           NaN
# 2               NaN                  NaN  HP:0007018           NaN
# 3               NaN                  NaN  HP:0005584           NaN
# 4               NaN                  NaN  HP:0005978           NaN
# 5               NaN                  NaN  HP:0005978           NaN
# 6               NaN                  NaN  HP:0012125           NaN
# 7               NaN                  NaN  HP:0012125           NaN
# 8               NaN                  NaN  HP:0005978           NaN
# 9               NaN                  NaN  HP:0005978           NaN
#
#    object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0         NaN              NaN              NaN                 NaN
# 1         NaN              NaN              NaN                 NaN
# 2         NaN              NaN              NaN                 NaN
# 3         NaN              NaN              NaN                 NaN
# 4         NaN              NaN              NaN                 NaN
# 5         NaN              NaN              NaN                 NaN
# 6         NaN              NaN              NaN                 NaN
# 7         NaN              NaN              NaN                 NaN
# 8         NaN              NaN              NaN                 NaN
# 9         NaN              NaN              NaN                 NaN
#
#    relation_id            relation_label  relation_iri
# 0  CustomRO:DC  is substance that treats           NaN
# 1  CustomRO:DC  is substance that treats           NaN
# 2  CustomRO:DC  is substance that treats           NaN
# 3  CustomRO:DC  is substance that treats           NaN
# 4  CustomRO:DC  is substance that treats           NaN
# 5  CustomRO:DC  is substance that treats           NaN
# 6  CustomRO:DC  is substance that treats           NaN
# 7  CustomRO:DC  is substance that treats           NaN
# 8  CustomRO:DC  is substance that treats           NaN
# 9  CustomRO:DC  is substance that treats           NaN

# %%
drugdiseases_associations_df.to_csv(f'../../{constants.OUTPUT_FOLDER}/{DISEASE_PREFIX}/prev_{DISEASE_PREFIX}_drugcentral_associations.csv', index=None)
