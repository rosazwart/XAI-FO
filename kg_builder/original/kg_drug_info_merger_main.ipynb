# %% [markdown]
# Merge all fetched datasets originating from Monarch Initiative, TTD and DrugCentral.
#
# Adapted by Rosa Zwart from Jupyter Notebook found at https://github.com/PPerdomoQ/rare-disease-explainer/blob/main/3_Predictions_and_explanations.ipynb

# %%
import os
import sys
import pandas as pd
import numpy as np

current_dir = os.getcwd()
project_root = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(project_root)

import util.constants as constants

# %%
DISEASE_PREFIX = 'oi'

# %% [markdown]
# #### **Format TTD data**

# %% [markdown]
# Save a list of all associations between DRUG and GENE in a csv file.

# %%
drug_targets = pd.read_csv(f'output/matched_drug_targets_{DISEASE_PREFIX}.csv')
drug_targets
# Out:
#            DRUG_NAME  STRUCT_ID  \
# 0        aclarubicin         80
# 1        aldosterone        111
# 2     aminoquinuride        174
# 3     androstenediol        214
# 4    androstenedione        215
# ..               ...        ...
# 203      pralsetinib       5412
# 204       filgotinib       5419
# 205       filgotinib       5419
# 206     infigratinib       5459
# 207     infigratinib       5459
#
#                                        TARGET_NAME TARGET_CLASS ACCESSION  \
# 0                       72 kDa type IV collagenase       Enzyme    P08253
# 1                     Sex hormone-binding globulin     Secreted    P04278
# 2                       Matrix metalloproteinase-9       Enzyme    P14780
# 3                     Sex hormone-binding globulin     Secreted    P04278
# 4                     Sex hormone-binding globulin     Secreted    P04278
# ..                                             ...          ...       ...
# 203   Platelet-derived growth factor receptor beta       Kinase    P09619
# 204  Vascular endothelial growth factor receptor 3       Kinase    P35916
# 205  Vascular endothelial growth factor receptor 3       Kinase    P35916
# 206  Vascular endothelial growth factor receptor 3       Kinase    P35916
# 207  Vascular endothelial growth factor receptor 3       Kinase    P35916
#
#        GENE    SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  ...  ACT_SOURCE  \
# 0      MMP2   MMP2_HUMAN       5.00       NaN     IC50  ...      CHEMBL
# 1      SHBG   SHBG_HUMAN       5.32       NaN       Kd  ...      CHEMBL
# 2      MMP9   MMP9_HUMAN       4.00       NaN     IC50  ...      CHEMBL
# 3      SHBG   SHBG_HUMAN       9.17       NaN       Kd  ...      CHEMBL
# 4      SHBG   SHBG_HUMAN       7.46       NaN       Kd  ...      CHEMBL
# ..      ...          ...        ...       ...      ...  ...         ...
# 203  PDGFRB  PGFRB_HUMAN       7.00       NaN     IC50  ...  DRUG LABEL
# 204    FLT4  VGFR3_HUMAN       6.56       NaN     IC50  ...      CHEMBL
# 205    FLT4  VGFR3_HUMAN       6.56       NaN     IC50  ...      CHEMBL
# 206    FLT4  VGFR3_HUMAN       5.68       NaN     IC50  ...      CHEMBL
# 207    FLT4  VGFR3_HUMAN       5.68       NaN     IC50  ...      CHEMBL
#
#     RELATION MOA  MOA_SOURCE  \
# 0          = NaN         NaN
# 1          = NaN         NaN
# 2          = NaN         NaN
# 3          = NaN         NaN
# 4          = NaN         NaN
# ..       ...  ..         ...
# 203        = NaN         NaN
# 204        = NaN         NaN
# 205        = NaN         NaN
# 206        = NaN         NaN
# 207        = NaN         NaN
#
#                                         ACT_SOURCE_URL MOA_SOURCE_URL  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 203  https://www.accessdata.fda.gov/drugsatfda_docs...            NaN
# 204                                                NaN            NaN
# 205                                                NaN            NaN
# 206                                                NaN            NaN
# 207                                                NaN            NaN
#
#     ACTION_TYPE    TDL      ORGANISM      NEW_ID
# 0           NaN  Tchem  Homo sapiens   HGNC:7166
# 1           NaN  Tchem  Homo sapiens  HGNC:10839
# 2           NaN  Tchem  Homo sapiens   HGNC:7176
# 3           NaN  Tchem  Homo sapiens  HGNC:10839
# 4           NaN  Tchem  Homo sapiens  HGNC:10839
# ..          ...    ...           ...         ...
# 203   INHIBITOR  Tclin  Homo sapiens   HGNC:8804
# 204         NaN  Tclin  Homo sapiens   HGNC:3767
# 205         NaN  Tclin  Homo sapiens   HGNC:3767
# 206         NaN  Tclin  Homo sapiens   HGNC:3767
# 207         NaN  Tclin  Homo sapiens   HGNC:3767
#
# [208 rows x 21 columns]

# %% [markdown]
# Get columns that are relevant.

# %%
drug_targets_values = drug_targets.copy()[['STRUCT_ID', 'DRUG_NAME', 'NEW_ID']]
drug_targets_values
# Out:
#      STRUCT_ID        DRUG_NAME      NEW_ID
# 0           80      aclarubicin   HGNC:7166
# 1          111      aldosterone  HGNC:10839
# 2          174   aminoquinuride   HGNC:7176
# 3          214   androstenediol  HGNC:10839
# 4          215  androstenedione  HGNC:10839
# ..         ...              ...         ...
# 203       5412      pralsetinib   HGNC:8804
# 204       5419       filgotinib   HGNC:3767
# 205       5419       filgotinib   HGNC:3767
# 206       5459     infigratinib   HGNC:3767
# 207       5459     infigratinib   HGNC:3767
#
# [208 rows x 3 columns]

# %%
drug_targets_values.drop_duplicates(inplace=True)
drug_targets_values.shape[0]
# Out:
# 203

# %% [markdown]
# Add new columns that are needed to be included in the dataframe.

# %%
dict_list = []

for i, row in drug_targets_values.iterrows():
    tuple_dict = {
        'id': f'TTD{i}',
        'subject_id': str(row['STRUCT_ID']),
        'subject_label': row['DRUG_NAME'],
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['NEW_ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:TTD',
        'relation_label': 'targets',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugtarget_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugtarget_associations_df
# Out:
#          id subject_id    subject_label  subject_iri subject_category  \
# 0      TTD0         80      aclarubicin          NaN             DRUG
# 1      TTD1        111      aldosterone          NaN             DRUG
# 2      TTD2        174   aminoquinuride          NaN             DRUG
# 3      TTD3        214   androstenediol          NaN             DRUG
# 4      TTD4        215  androstenedione          NaN             DRUG
# ..      ...        ...              ...          ...              ...
# 198  TTD201       5389        tucatinib          NaN             DRUG
# 199  TTD202       5394       ripretinib          NaN             DRUG
# 200  TTD203       5412      pralsetinib          NaN             DRUG
# 201  TTD204       5419       filgotinib          NaN             DRUG
# 202  TTD206       5459     infigratinib          NaN             DRUG
#
#      subject_taxon_id  subject_taxon_label   object_id  object_label  \
# 0                 NaN                  NaN   HGNC:7166           NaN
# 1                 NaN                  NaN  HGNC:10839           NaN
# 2                 NaN                  NaN   HGNC:7176           NaN
# 3                 NaN                  NaN  HGNC:10839           NaN
# 4                 NaN                  NaN  HGNC:10839           NaN
# ..                ...                  ...         ...           ...
# 198               NaN                  NaN   HGNC:3236           NaN
# 199               NaN                  NaN   HGNC:8804           NaN
# 200               NaN                  NaN   HGNC:8804           NaN
# 201               NaN                  NaN   HGNC:3767           NaN
# 202               NaN                  NaN   HGNC:3767           NaN
#
#      object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0           NaN              NaN              NaN                 NaN
# 1           NaN              NaN              NaN                 NaN
# 2           NaN              NaN              NaN                 NaN
# 3           NaN              NaN              NaN                 NaN
# 4           NaN              NaN              NaN                 NaN
# ..          ...              ...              ...                 ...
# 198         NaN              NaN              NaN                 NaN
# 199         NaN              NaN              NaN                 NaN
# 200         NaN              NaN              NaN                 NaN
# 201         NaN              NaN              NaN                 NaN
# 202         NaN              NaN              NaN                 NaN
#
#       relation_id relation_label  relation_iri
# 0    CustomRO:TTD        targets           NaN
# 1    CustomRO:TTD        targets           NaN
# 2    CustomRO:TTD        targets           NaN
# 3    CustomRO:TTD        targets           NaN
# 4    CustomRO:TTD        targets           NaN
# ..            ...            ...           ...
# 198  CustomRO:TTD        targets           NaN
# 199  CustomRO:TTD        targets           NaN
# 200  CustomRO:TTD        targets           NaN
# 201  CustomRO:TTD        targets           NaN
# 202  CustomRO:TTD        targets           NaN
#
# [203 rows x 16 columns]

# %%
drugtarget_associations_df.to_csv(f'../../{constants.OUTPUT_FOLDER}/{DISEASE_PREFIX}/prev_{DISEASE_PREFIX}_ttd_associations.csv', index=None)

# %% [markdown]
# #### **Format DrugCentral data**

# %%
drug_diseases = pd.read_csv(f'output/matched_drug_to_disease_{DISEASE_PREFIX}.csv')
drug_diseases
# Out:
#     Unnamed: 0  DRUG_ID        DRUG_NAME                        DISEASES  \
# 0          878     1932        Nilotinib  Chronic myelogenous leukaemia
# 1         1167     1879       Nandrolone                   Osteoporosis
# 2         1291      542        Cefonicid            Bacterial infection
# 3         1945      574        Cefalotin            Bacterial infection
# 4         2262     2351       Raloxifene                   Osteoporosis
# 5         5006     4138   Gentian violet            Bacterial infection
# 6         7442      576        Cefradine            Bacterial infection
# 7         8028     2607     Testosterone                   Osteoporosis
# 8         8752     4977       Siltuximab                         Anemia
# 9         9195      960      Doxorubicin                         Tumour
# 10       12293      547        Cefotetan            Bacterial infection
# 11       12354     1423         Imatinib  Chronic myelogenous leukaemia
# 12       12748     1762       Methyldopa                   Hypertension
# 13       13499      700        Clomifene             Female infertility
# 14       13982     1610         Losartan                   Hypertension
# 15       14470      785        Dasatinib  Chronic myelogenous leukaemia
# 16       16688      111      Aldosterone                   Hypertension
# 17       16693      785        Dasatinib      Chronic myeloid leukaemia
# 18       17544      937       Dobutamine                  Heart failure
# 19       18177     3514        Quercetin                        Obesity
# 20       18307     1423         Imatinib      Chronic myeloid leukaemia
# 21       18385     1388   Hydrocortisone                   Inflammation
# 22       19096      281       Bacitracin                 Skin infection
# 23       20415     1610         Losartan                   Hypertension
# 24       21875     2666  Tiludronic acid                   Osteoporosis
# 25       24637      597    Chlorhexidine            Bacterial infection
# 26       25658     4209         Prazosin       Congestive heart failure
# 27       25660     4209         Prazosin                   Hypertension
# 28       27493     1364  Hexachlorophene            Bacterial infection
#
#              PHASE                           Name  \
# 0         Approved  chronic myelogenous leukaemia
# 1         Approved                   osteoporosis
# 2         Approved            bacterial infection
# 3         Approved            bacterial infection
# 4         Approved                   osteoporosis
# 5         Approved            bacterial infection
# 6         Approved            bacterial infection
# 7         Approved                   osteoporosis
# 8         Approved                         anemia
# 9    Investigative                         tumour
# 10        Approved            bacterial infection
# 11        Approved  chronic myelogenous leukaemia
# 12        Approved                   hypertension
# 13        Approved             female infertility
# 14        Approved                   hypertension
# 15        Approved  chronic myelogenous leukaemia
# 16        Approved                   hypertension
# 17        Approved      chronic myeloid leukaemia
# 18        Approved                  heart failure
# 19        Approved                        obesity
# 20        Approved      chronic myeloid leukaemia
# 21        Approved                   inflammation
# 22        Approved                 skin infection
# 23        Approved                   hypertension
# 24        Approved                   osteoporosis
# 25        Approved            bacterial infection
# 26        Approved       congestive heart failure
# 27        Approved                   hypertension
# 28        Approved            bacterial infection
#
#                  ontologyTermName                            ontologyTermIRI  \
# 0    Chronic myelogenous leukemia  http://purl.obolibrary.org/obo/HP_0005506
# 1                    Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 2                      Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 3                      Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 4                    Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 5                      Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 6                      Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 7                    Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 8                          Anemia  http://purl.obolibrary.org/obo/HP_0001903
# 9                        Neoplasm  http://purl.obolibrary.org/obo/HP_0002664
# 10                     Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 11   Chronic myelogenous leukemia  http://purl.obolibrary.org/obo/HP_0005506
# 12                   Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 13             Female infertility  http://purl.obolibrary.org/obo/HP_0008222
# 14                   Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 15   Chronic myelogenous leukemia  http://purl.obolibrary.org/obo/HP_0005506
# 16                   Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 17   Chronic myelogenous leukemia  http://purl.obolibrary.org/obo/HP_0005506
# 18       Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 19                        Obesity  http://purl.obolibrary.org/obo/HP_0001513
# 20   Chronic myelogenous leukemia  http://purl.obolibrary.org/obo/HP_0005506
# 21  Gastrointestinal inflammation  http://purl.obolibrary.org/obo/HP_0004386
# 22                     Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 23                   Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 24                   Osteoporosis  http://purl.obolibrary.org/obo/HP_0000939
# 25                     Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
# 26       Congestive heart failure  http://purl.obolibrary.org/obo/HP_0001635
# 27                   Hypertension  http://purl.obolibrary.org/obo/HP_0000822
# 28                     Cellulitis  http://purl.obolibrary.org/obo/HP_0100658
#
#     validated  review          ID
# 0       False   False  HP:0005506
# 1       False   False  HP:0000939
# 2       False   False  HP:0100658
# 3       False   False  HP:0100658
# 4       False   False  HP:0000939
# 5       False   False  HP:0100658
# 6       False   False  HP:0100658
# 7       False   False  HP:0000939
# 8       False   False  HP:0001903
# 9       False   False  HP:0002664
# 10      False   False  HP:0100658
# 11      False   False  HP:0005506
# 12      False   False  HP:0000822
# 13      False   False  HP:0008222
# 14      False   False  HP:0000822
# 15      False   False  HP:0005506
# 16      False   False  HP:0000822
# 17      False   False  HP:0005506
# 18      False   False  HP:0001635
# 19      False   False  HP:0001513
# 20      False   False  HP:0005506
# 21      False   False  HP:0004386
# 22      False   False  HP:0100658
# 23      False   False  HP:0000822
# 24      False   False  HP:0000939
# 25      False   False  HP:0100658
# 26      False   False  HP:0001635
# 27      False   False  HP:0000822
# 28      False   False  HP:0100658

# %%
drug_diseases_values = drug_diseases.copy()[['DRUG_ID', 'ID']]
drug_diseases_values
# Out:
#     DRUG_ID          ID
# 0      1932  HP:0005506
# 1      1879  HP:0000939
# 2       542  HP:0100658
# 3       574  HP:0100658
# 4      2351  HP:0000939
# 5      4138  HP:0100658
# 6       576  HP:0100658
# 7      2607  HP:0000939
# 8      4977  HP:0001903
# 9       960  HP:0002664
# 10      547  HP:0100658
# 11     1423  HP:0005506
# 12     1762  HP:0000822
# 13      700  HP:0008222
# 14     1610  HP:0000822
# 15      785  HP:0005506
# 16      111  HP:0000822
# 17      785  HP:0005506
# 18      937  HP:0001635
# 19     3514  HP:0001513
# 20     1423  HP:0005506
# 21     1388  HP:0004386
# 22      281  HP:0100658
# 23     1610  HP:0000822
# 24     2666  HP:0000939
# 25      597  HP:0100658
# 26     4209  HP:0001635
# 27     4209  HP:0000822
# 28     1364  HP:0100658

# %%
dict_list = []

for i, row in drug_diseases_values.iterrows():
    tuple_dict = {
        'id': f'DC{i}',
        'subject_id': row['DRUG_ID'],
        'subject_label': np.nan,
        'subject_iri': np.nan,
        'subject_category': 'DRUG',
        'subject_taxon_id': np.nan,
        'subject_taxon_label': np.nan,
        'object_id': row['ID'],
        'object_label': np.nan,
        'object_iri': np.nan,
        'object_category': np.nan,
        'object_taxon_id': np.nan,
        'object_taxon_label': np.nan,
        'relation_id': 'CustomRO:DC',
        'relation_label': 'is substance that treats',
        'relation_iri': np.nan
    }

    dict_list.append(tuple_dict)

drugdiseases_associations_df = pd.DataFrame.from_dict(dict_list)

# %%
drugdiseases_associations_df.head(10)
# Out:
#     id  subject_id  subject_label  subject_iri subject_category  \
# 0  DC0        1932            NaN          NaN             DRUG
# 1  DC1        1879            NaN          NaN             DRUG
# 2  DC2         542            NaN          NaN             DRUG
# 3  DC3         574            NaN          NaN             DRUG
# 4  DC4        2351            NaN          NaN             DRUG
# 5  DC5        4138            NaN          NaN             DRUG
# 6  DC6         576            NaN          NaN             DRUG
# 7  DC7        2607            NaN          NaN             DRUG
# 8  DC8        4977            NaN          NaN             DRUG
# 9  DC9         960            NaN          NaN             DRUG
#
#    subject_taxon_id  subject_taxon_label   object_id  object_label  \
# 0               NaN                  NaN  HP:0005506           NaN
# 1               NaN                  NaN  HP:0000939           NaN
# 2               NaN                  NaN  HP:0100658           NaN
# 3               NaN                  NaN  HP:0100658           NaN
# 4               NaN                  NaN  HP:0000939           NaN
# 5               NaN                  NaN  HP:0100658           NaN
# 6               NaN                  NaN  HP:0100658           NaN
# 7               NaN                  NaN  HP:0000939           NaN
# 8               NaN                  NaN  HP:0001903           NaN
# 9               NaN                  NaN  HP:0002664           NaN
#
#    object_iri  object_category  object_taxon_id  object_taxon_label  \
# 0         NaN              NaN              NaN                 NaN
# 1         NaN              NaN              NaN                 NaN
# 2         NaN              NaN              NaN                 NaN
# 3         NaN              NaN              NaN                 NaN
# 4         NaN              NaN              NaN                 NaN
# 5         NaN              NaN              NaN                 NaN
# 6         NaN              NaN              NaN                 NaN
# 7         NaN              NaN              NaN                 NaN
# 8         NaN              NaN              NaN                 NaN
# 9         NaN              NaN              NaN                 NaN
#
#    relation_id            relation_label  relation_iri
# 0  CustomRO:DC  is substance that treats           NaN
# 1  CustomRO:DC  is substance that treats           NaN
# 2  CustomRO:DC  is substance that treats           NaN
# 3  CustomRO:DC  is substance that treats           NaN
# 4  CustomRO:DC  is substance that treats           NaN
# 5  CustomRO:DC  is substance that treats           NaN
# 6  CustomRO:DC  is substance that treats           NaN
# 7  CustomRO:DC  is substance that treats           NaN
# 8  CustomRO:DC  is substance that treats           NaN
# 9  CustomRO:DC  is substance that treats           NaN

# %%
drugdiseases_associations_df.to_csv(f'../../{constants.OUTPUT_FOLDER}/{DISEASE_PREFIX}/prev_{DISEASE_PREFIX}_drugcentral_associations.csv', index=None)
