# %% [markdown]
# Taken from https://github.com/PPerdomoQ/rare-disease-explainer/blob/main/2_Add_drug_info.ipynb with adjustments

# %% [markdown]
# ## **Import**

# %%
import re
import pandas as pd
import numpy as np

import requests
import time

# %% [markdown]
# ## Parameters

# %%
DISEASE_PREFIX = 'oi'

# %% [markdown]
# ## **Drug-Target Information**

# %% [markdown]
# ### **Load Files**

# %% [markdown]
# Load the information from Drug Central and Monarch:

# %%
df = pd.read_csv('../../input/drug.target.interaction.tsv', header=0, index_col=0, sep='\t')
nodes = pd.read_csv(f'output/prev_{DISEASE_PREFIX}_monarch_nodes.csv', header=0)

# %%
print(len(nodes))
nodes.head(5)
# Out:
# 9732
#                            id semantic_groups  \
# 0  ENSEMBL:ENSCAFG00000008883            ORTH
# 1  ENSEMBL:ENSECAG00000025065            ORTH
# 2                   HGNC:8799            GENE
# 3      ZFIN:ZDB-GENE-100623-1            ORTH
# 4                  ZP:0002795            DISO
#
#                                      name
# 0                                    TLL1
# 1              ENSEMBL:ENSECAG00000025065
# 2                                   PDGFA
# 3                                  thbs2b
# 4  axon MiP motor neuron absent, abnormal

# %%
df
# Out:
#                  STRUCT_ID                                        TARGET_NAME  \
# DRUG_NAME
# levobupivacaine          4  Potassium voltage-gated channel subfamily H me...
# levobupivacaine          4        Sodium channel protein type 1 subunit alpha
# levobupivacaine          4        Sodium channel protein type 4 subunit alpha
# levobupivacaine          4              Prostaglandin E2 receptor EP1 subtype
# levobupivacaine          4                                Cytochrome P450 2D6
# ...                    ...                                                ...
# samidorphan           5460                         Delta-type opioid receptor
# sotorasib             5461                                        GTPase KRas
# ibrexafungerp         5462       Beta-1,3-glucan synthase catalytic subunit 1
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
# ibrexafungerp         5462          1,3-Beta-D-glucan-UDP glucosyltransferase
#
#                 TARGET_CLASS ACCESSION    GENE     SWISSPROT  ACT_VALUE  \
# DRUG_NAME
# levobupivacaine  Ion channel    Q12809   KCNH2   KCNH2_HUMAN      4.890
# levobupivacaine  Ion channel    P35498   SCN1A   SCN1A_HUMAN      5.790
# levobupivacaine  Ion channel    P35499   SCN4A   SCN4A_HUMAN        NaN
# levobupivacaine         GPCR    P34995  PTGER1   PE2R1_HUMAN        NaN
# levobupivacaine       Enzyme    P10635  CYP2D6   CP2D6_HUMAN      6.707
# ...                      ...       ...     ...           ...        ...
# samidorphan             GPCR    P41143   OPRD1    OPRD_HUMAN      8.590
# sotorasib             Enzyme    P01116    KRAS    RASK_HUMAN      7.030
# ibrexafungerp         Enzyme    O13428    GSC1  O13428_CANAX      8.350
# ibrexafungerp         Enzyme    Q6FTN8    FKS1  Q6FTN8_CANGA      7.830
# ibrexafungerp         Enzyme    P87204     FKS  P87204_ASPFM      8.970
#
#                  ACT_UNIT ACT_TYPE  \
# DRUG_NAME
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN     IC50
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN      NaN
# levobupivacaine       NaN     IC50
# ...                   ...      ...
# samidorphan           NaN       Ki
# sotorasib             NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
# ibrexafungerp         NaN     IC50
#
#                                                        ACT_COMMENT  \
# DRUG_NAME
# levobupivacaine  Inhibition of wild-type human ERG channel expr...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib                                       KRAS G12C mutation
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
# ibrexafungerp    MoA - inhibits the biosynthesis of beta-(1,3)-...
#
#                             ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# DRUG_NAME
# levobupivacaine                 CHEMBL        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK        =  NaN                    NaN
# levobupivacaine              WOMBAT-PK      NaN  1.0                 CHEMBL
# levobupivacaine              WOMBAT-PK      NaN  NaN                    NaN
# levobupivacaine            DRUG MATRIX        =  NaN                    NaN
# ...                                ...      ...  ...                    ...
# samidorphan                 DRUG LABEL        =  NaN                    NaN
# sotorasib                   DRUG LABEL        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# ibrexafungerp    SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
#
#                                                     ACT_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan      https://www.accessdata.fda.gov/drugsatfda_docs...
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
# ibrexafungerp             https://pubmed.ncbi.nlm.nih.gov/24323472
#
#                                                     MOA_SOURCE_URL  \
# DRUG_NAME
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# levobupivacaine  https://www.ebi.ac.uk/chembl/compound/inspect/...
# levobupivacaine                                                NaN
# levobupivacaine                                                NaN
# ...                                                            ...
# samidorphan                                                    NaN
# sotorasib        https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
# ibrexafungerp    https://www.accessdata.fda.gov/drugsatfda_docs...
#
#                      ACTION_TYPE    TDL              ORGANISM
# DRUG_NAME
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine          BLOCKER  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# levobupivacaine              NaN  Tclin          Homo sapiens
# ...                          ...    ...                   ...
# samidorphan      PARTIAL AGONIST  Tclin          Homo sapiens
# sotorasib              INHIBITOR  Tchem          Homo sapiens
# ibrexafungerp          INHIBITOR    NaN      Candida albicans
# ibrexafungerp          INHIBITOR    NaN      Candida glabrata
# ibrexafungerp          INHIBITOR    NaN  Neosartorya fumigata
#
# [19378 rows x 19 columns]

# %%
df['NEW_ID'] = ''

# %% [markdown]
# ### **Uniprot to Monarch IDs**

# %% [markdown]
# Use Uniprot API to obtain new target IDs:

# %%
"""
    @description: This module maps UniProt accession IDs to other databases depending on taxon. 
    @source: https://www.uniprot.org/help/id_mapping
    @author: Rosa Zwart
"""

RETRIES = 3
POLLING_S_INTERVAL = 5

FROM_DB = 'UniProtKB_AC-ID'
DEFAULT_TO_DB = 'Ensembl'

db_mapper = {
    'Homo sapiens': 'HGNC',
    'Rattus norvegicus': 'RGD',
    'Mus musculus': 'MGI',
    'Drosophila melanogaster': 'FlyBase',
    'Caenorhabditis elegans': 'WormBase',
    'Danio rerio': 'ZFIN',
    'Escherichia coli': 'EnsemblGenome',
    'Xenopus tropicalis': 'Xenbase',
    'Dictyostelium discoideum': 'dictyBase',
    'Saccharomyces cerevisiae S288C': 'SGD',
    'Schizosaccharomyces pombe': 'PomBase'
}

class IdMapper:
    def __init__(self, ids_to_map: list, to_db = DEFAULT_TO_DB, from_db = FROM_DB):
        self.url = 'https://rest.uniprot.org'
        self.job_id = self.submit_id_mapping(ids_to_map, to_db, from_db)

        if self.check_job_ready():
            self.results = self.get_results()
        
    def submit_id_mapping(self, id_list, to_db, from_db):
        print(f'Map to database {to_db}')
        
        data_params = {
            'from': from_db,
            'to': to_db,
            'ids': ','.join(id_list)
        }
        
        for i in range(RETRIES):
            try:  
                response = requests.post(f'{self.url}/idmapping/run', data=data_params)
                response.raise_for_status()
                return response.json()['jobId']
            except Exception as e:
                if (i < RETRIES - 1):
                    print(f'Retrying in {POLLING_S_INTERVAL}s')
                    time.sleep(POLLING_S_INTERVAL)
                    continue
                else:
                    print(f'After all attempts, request could not be submitted due to {e}')
                    return None
                
    def check_job_ready(self):
        while self.job_id:
            try:
                response = requests.get(f'{self.url}/idmapping/status/{self.job_id}')
                response.raise_for_status()
                response_values = response.json()
                if 'jobStatus' in response_values:
                    if response_values['jobStatus'] == 'RUNNING':
                        print(f'Check again after {POLLING_S_INTERVAL}s')
                        time.sleep(POLLING_S_INTERVAL)
                    
                    elif response_values['jobStatus'] == 'FINISHED':
                        print('Job is finished')
                        return True
                    
                    else:
                        print(f'Job {self.job_id} had status {response_values["jobStatus"]}, stopped checking if job is ready.')
                        return False
                elif 'results' in response_values:
                        return True
                else:
                    return False
            except Exception as e:
                print(f'Failed to check whether job is finished due to {e}, try again after {POLLING_S_INTERVAL}s...')
                time.sleep(POLLING_S_INTERVAL)
                
    def get_results(self):
        for i in range(RETRIES):
            try:  
                response = requests.get(f'{self.url}/idmapping/stream/{self.job_id}')
                response.raise_for_status()
                return response.json()['results']
            except Exception as e:
                if (i < RETRIES - 1):
                    print(f'Retrying in {POLLING_S_INTERVAL}s')
                    time.sleep(POLLING_S_INTERVAL)
                    continue
                else:
                    print(f'After all attempts, request could not be submitted due to {e}')
                    return None

# %%
def get_single_id(id):
    """
        Get from list of IDs split by `|`, one ID.
        :return Single ID value
    """
    split_id = id.split('|')
    if len(split_id) > 1:
        return split_id[0]
    else:
        return id

def fetch_id_mappings(entries: pd.DataFrame, map_to_db):
    """
        Get ID mappings of IDs present in given dataframe. Mappings are based on given database to which the IDs need to be mapped.
        :param entries: Dataframe containing column name `ACCESSION`
        :param map_to_db: Name of database to which the given IDs need to be mapped
    """
    if (entries.shape[0] > 0):
        id_entries_to_map = entries.copy()
        id_entries_to_map['ACCESSION'] = entries.apply(lambda row: get_single_id(row['ACCESSION']), axis=1)
        
        mapper = IdMapper(ids_to_map=id_entries_to_map['ACCESSION'].to_list(), to_db=map_to_db)
        if hasattr(mapper, 'results'):
            return mapper.results
        else:
            return []
    else:
        return []

def get_mapped_ids(drug_targets):
    """
        Get mapped IDs for all included databases.
        :param drug_targets: Dataframe that contains column name `ORGANISM` and `ACCESSION`
    """
    all_mapped_id_results = []
    all_taxon_names = list(db_mapper.keys())
    
    for taxon in all_taxon_names:
        relevant_entries = drug_targets[drug_targets['ORGANISM'].str.contains(taxon)]
        id_mappings = fetch_id_mappings(relevant_entries, db_mapper[taxon])
        all_mapped_id_results = all_mapped_id_results + id_mappings

    # Map entity ids of leftover organisms to default database
    other_relevant_entries = drug_targets[~drug_targets['ORGANISM'].isin(all_taxon_names)]
    other_id_mappings = fetch_id_mappings(other_relevant_entries, DEFAULT_TO_DB)
    all_mapped_id_results = all_mapped_id_results + other_id_mappings
                
    return all_mapped_id_results

results = get_mapped_ids(drug_targets=df)
# Out:
# Map to database HGNC
# Map to database RGD
# Map to database MGI
# Map to database FlyBase
# Map to database WormBase
# Map to database ZFIN
# Map to database EnsemblGenome
# Retrying in 5s
# Retrying in 5s
# After all attempts, request could not be submitted due to 400 Client Error:  for url: https://rest.uniprot.org/idmapping/run
# Map to database PomBase
# Map to database Ensembl

# %%
def check_split_values(value, id_value):
    parts = value.split('|')
    return all(part == id_value for part in parts)

for mapping_result in results:
    original_id = mapping_result['from']
    new_id = mapping_result['to']
    
    df.loc[df['ACCESSION'].apply(check_split_values, id_value=original_id), 'NEW_ID'] = new_id

# %%
df['NEW_ID'] = df['NEW_ID'].replace('', np.nan)

# %%
print(f'Tried to match IDs to ACCESSION IDs for {len(df)} rows.')
# Out:
# Tried to match IDs to ACCESSION IDs for 19378 rows.

# %% [markdown]
# Drop rows that don't have a new ID:

# %%
df = df.dropna(subset=['NEW_ID'])
print(f'All found matched IDs to ACCESSION IDs for {len(df)} rows.')
# Out:
# All found matched IDs to ACCESSION IDs for 16141 rows.

# %% [markdown]
# Keep only rows whose the target is in the Monarch nodes:

# %%
df = df[df['NEW_ID'].isin(list(nodes['id']))]
print(f'All targets that match with Monarch nodes consisting of {len(df)} rows.')
# Out:
# All targets that match with Monarch nodes consisting of 208 rows.

# %% [markdown]
# Save the Drug-Target dataframe as .csv:

# %%
df.to_csv(f'output/matched_drug_targets_{DISEASE_PREFIX}.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Create and save a dataframe containing the drug nodes:

# %%
df['DRUG_NAME'] = df.index
df_drugs = df[['DRUG_NAME', 'STRUCT_ID']]
df_drugs = df_drugs.drop_duplicates()
df_drugs.to_csv(f'output/drug_nodes_{DISEASE_PREFIX}.csv', encoding = 'utf-8-sig')

# %%
df_drugs.head(10)
# Out:
#                                              DRUG_NAME  STRUCT_ID
# DRUG_NAME
# aclarubicin                                aclarubicin         80
# aldosterone                                aldosterone        111
# aminoquinuride                          aminoquinuride        174
# androstenediol                          androstenediol        214
# androstenedione                        androstenedione        215
# astemizole                                  astemizole        249
# bacitracin                                  bacitracin        281
# beclometasone dipropionate  beclometasone dipropionate        294
# budesonide                                  budesonide        419
# busulfan                                      busulfan        438

# %%
len(df_drugs)
# Out:
# 153

# %% [markdown]
# ## **Drug-Disease Information**

# %% [markdown]
# ### **Text to CSV**

# %% [markdown]
# If already saved, run only the cell of this section, otherwise continue:

# %% [markdown]
# Create a Dataframe that will contain the Drug-Disease information:

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

# %% [markdown]
# Read the .txt file downloaded from TTD and convert it into a pandas dataframe:

# %%
with open('../../input/P1-05-Drug_disease.txt') as f:
  lines = f.readlines()[22:]

# %%
i = 0
id = ''
name = ''
disease = ''
phase = ''

for line in lines: 
  if line.startswith('DRUGNAME'): 
    result = re.search('\t(.*)\n', line)
    name = result.group(1)
  elif line.startswith('TTDDRUID'): 
    result = re.search('\t(.*)\n', line)
    id = result.group(1)
  elif line.startswith('INDICATI'): 
    result = re.search('\t(.*)\[', line)
    result2 = re.search('\](.*)', line)
    disease = result.group(1) 
    phase = result2.group(1) 
    df.loc[i] = [id,name,disease, phase]
    i += 1
  elif line.startswith('\n'): 
    id = ''
    name = ''
    disease = ''
    phase = ''
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\['
# <>:16: SyntaxWarning: invalid escape sequence '\]'
# <>:15: SyntaxWarning: invalid escape sequence '\['
# <>:16: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_19272\1061029482.py:15: SyntaxWarning: invalid escape sequence '\['
#   result = re.search('\t(.*)\[', line)
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_19272\1061029482.py:16: SyntaxWarning: invalid escape sequence '\]'
#   result2 = re.search('\](.*)', line)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('output/drug_to_disease.csv', encoding = 'utf-8-sig')

# %% [markdown]
# Run only this cell if you have already saved the Drug-Disease interactions:

# %%
df = pd.read_csv('output/drug_to_disease.csv', header=0, index_col=0)

# %%
df
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 28973  DZTX12        ASC-J9                   End-stage renal disease
# 28974  DZU72C       OKI 179                       Solid tumour/cancer
# 28975  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 28976  DZW53X    GSK4069889                Non-small cell lung cancer
# 28977  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE
# 0                       Phase 2
# 1                       Phase 2
# 2                       Phase 1
# 3       Discontinued in Phase 1
# 4       Discontinued in Phase 1
# ...                         ...
# 28973                   Phase 2
# 28974                   Phase 1
# 28975            Clinical Trial
# 28976                   Phase 2
# 28977                   Phase 1
#
# [28978 rows x 4 columns]

# %%
df.to_csv('output/drug_to_disease.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Load CSVs**

# %% [markdown]
# Load the drug nodes (obtained from Drug Central) and the Monarch nodes:

# %%
graph_drugs = pd.read_csv(f'output/drug_nodes_{DISEASE_PREFIX}.csv', header=0)
nodes = pd.read_csv(f'output/prev_{DISEASE_PREFIX}_monarch_nodes.csv', header=0)

# %% [markdown]
# Get list of unique drugs and diseases:

# %%
graph_diseases = nodes[nodes['semantic_groups'] == 'DISO']

unique_diseases = graph_diseases['name'].unique()
unique_dis_id = graph_diseases['id'].unique()
unique_diseases = [x.lower() for x in unique_diseases]

print(f'There are {len(unique_diseases)} diseases found in Monarch nodes.')
# Out:
# There are 5313 diseases found in Monarch nodes.

# %%
unique_drugs = graph_drugs['DRUG_NAME'].unique()
unique_drugs = [x.lower() for x in unique_drugs]
print(f'There are {len(unique_drugs)} unique drugs found in DrugCentral entries.')
# Out:
# There are 153 unique drugs found in DrugCentral entries.

# %% [markdown]
# At this point you should use SORTA tool (https://sorta.molgeniscloud.org/menu/main/sorta?) to match the IDs of TTD to Human Phenotype Ontology (HPO). The file is also available in the project's Github:

# %%
matched = pd.read_csv('../../input/matched_phenotypes.csv', header = 0, delimiter = ';')

# %%
matched
# Out:
#                                                    Name  \
# 0                                   respiratory failure
# 1                                    sexual dysfunction
# 2                                        achondroplasia
# 3                                  glabellar frown line
# 4                           testicular germ cell tumour
# ...                                                 ...
# 1796                              systemic mastocytosis
# 1797                    acute iron or aluminum toxicity
# 1798  chronic inflammatory demyelinating polyneuropathy
# 1799                                    aortic aneurysm
# 1800                                              fever
#
#                           ontologyTermName  \
# 0                      Respiratory failure
# 1                  Male sexual dysfunction
# 2                         Bronchodysplasia
# 3                       Prominent glabella
# 4                      Testicular neoplasm
# ...                                    ...
# 1796                          Mastocytosis
# 1797  Abnormal total iron binding capacity
# 1798    Acute demyelinating polyneuropathy
# 1799                       Aortic aneurysm
# 1800                                 Fever
#
#                                 ontologyTermIRI   score  validated  review
# 0     http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1     http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 2     http://purl.obolibrary.org/obo/HP_0006533   62.50      False   False
# 3     http://purl.obolibrary.org/obo/HP_0002057   59.46      False   False
# 4     http://purl.obolibrary.org/obo/HP_0010788   71.11      False   False
# ...                                         ...     ...        ...     ...
# 1796  http://purl.obolibrary.org/obo/HP_0100495   77.42      False   False
# 1797  http://purl.obolibrary.org/obo/HP_0033212   48.15      False   False
# 1798  http://purl.obolibrary.org/obo/HP_0007131   64.86      False   False
# 1799  http://purl.obolibrary.org/obo/HP_0004942  100.00      False   False
# 1800  http://purl.obolibrary.org/obo/HP_0001945  100.00      False   False
#
# [1801 rows x 6 columns]

# %% [markdown]
# Select only those IDs with a score greater than 80:

# %%
matched = matched[matched['score'] > 80]

# %% [markdown]
# Create the final ID:

# %%
matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_19272\1934371214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = matched['ontologyTermIRI'].str.split('/obo/').str[1]

# %%
new_id = []
for i in matched['ID']: 
  id_value = re.sub("[^0-9a-zA-Z]+", ":", i)
  new_id.append(id_value)
matched['ID'] = new_id
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_19272\586493346.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['ID'] = new_id

# %%
matched.head(10)
# Out:
#                                         Name  \
# 0                        respiratory failure
# 1                         sexual dysfunction
# 6                                pollakiuria
# 17                             dental caries
# 22   hematopoietic stem cell transplantation
# 25                                 gastritis
# 26                                arthralgia
# 27  attention deficit hyperactivity disorder
# 28                       female hypogonadism
# 29                     vitamin b1 deficiency
#
#                             ontologyTermName  \
# 0                        Respiratory failure
# 1                    Male sexual dysfunction
# 6                               Pollakisuria
# 17                             Carious teeth
# 22         History of bone marrow transplant
# 25                                 Gastritis
# 26                                Arthralgia
# 27  Attention deficit hyperactivity disorder
# 28                       Female hypogonadism
# 29                  Low levels of vitamin B1
#
#                               ontologyTermIRI   score  validated  review  \
# 0   http://purl.obolibrary.org/obo/HP_0002878  100.00      False   False
# 1   http://purl.obolibrary.org/obo/HP_0040307   86.49      False   False
# 6   http://purl.obolibrary.org/obo/HP_0100515   88.00      False   False
# 17  http://purl.obolibrary.org/obo/HP_0000670  100.00      False   False
# 22  http://purl.obolibrary.org/obo/HP_0032557   85.71      False   False
# 25  http://purl.obolibrary.org/obo/HP_0005263  100.00      False   False
# 26  http://purl.obolibrary.org/obo/HP_0002829  100.00      False   False
# 27  http://purl.obolibrary.org/obo/HP_0007018  100.00      False   False
# 28  http://purl.obolibrary.org/obo/HP_0000134  100.00      False   False
# 29  http://purl.obolibrary.org/obo/HP_0100503  100.00      False   False
#
#             ID
# 0   HP:0002878
# 1   HP:0040307
# 6   HP:0100515
# 17  HP:0000670
# 22  HP:0032557
# 25  HP:0005263
# 26  HP:0002829
# 27  HP:0007018
# 28  HP:0000134
# 29  HP:0100503

# %% [markdown]
# ### **Merging**

# %%
modified = []
for d in df['DISEASES']: 
  new_string = re.sub("[^0-9a-zA-Z]+", " ", d)
  modified.append(new_string.lower())
modified
# Out:
# ['ischemia ',
#  'peripheral arterial disease ',
#  'acute myeloid leukaemia ',
#  'hormone deficiency ',
#  'depression ',
#  'bacterial infection ',
#  'solid tumour cancer ',
#  'gram positive bacterial infection ',
#  'solid tumour cancer ',
#  'recurrent glioblastoma ',
#  'human immunodeficiency virus infection ',
#  'non small cell lung cancer ',
#  'metastatic melanoma ',
#  'melanoma ',
#  'central nervous system disease ',
#  'solid tumour cancer ',
#  'mycobacterium infection ',
#  'neuropathic pain ',
#  'non insulin dependent diabetes ',
#  'influenza virus infection ',
#  'chronic obstructive pulmonary disease ',
#  'breast cancer ',
#  'liver disease ',
#  'asthma ',
#  'influenza virus infection ',
#  'peripheral vascular disease ',
#  'cystitis ',
#  'chronic pain ',
#  'anemia ',
#  'herpes simplex virus infection ',
#  'middle east respiratory syndrome mers ',
#  'small cell lung cancer ',
#  'obesity ',
#  'cystic fibrosis ',
#  'type 1 diabetes ',
#  'type 2 diabetes ',
#  'salmonella infection ',
#  'hyperlipidaemia ',
#  'diagnostic imaging ',
#  'neuropathic pain ',
#  'type 2 diabetes ',
#  'inflammation ',
#  'hepatitis b virus infection ',
#  'bacterial infection ',
#  'emphysema ',
#  'psychiatric disorder ',
#  'non insulin dependent diabetes ',
#  'fungal infection ',
#  'solid tumour cancer ',
#  'diabetic angiopathy ',
#  'solid tumour cancer ',
#  'type 2 diabetes ',
#  'hypertension ',
#  'breast cancer ',
#  'non insulin dependent diabetes ',
#  'panic disorder ',
#  'reperfusion injury ',
#  'otitis media ',
#  'ovarian cancer ',
#  'hypertension ',
#  'solid tumour cancer ',
#  'type 2 diabetes ',
#  'overactive bladder ',
#  'plaque psoriasis ',
#  'ovarian cancer ',
#  'breast cancer ',
#  'ewing sarcoma ',
#  'solid tumour cancer ',
#  'cluster headache ',
#  'migraine ',
#  'non hodgkin lymphoma ',
#  'breast cancer ',
#  'psoriasis vulgaris ',
#  'human immunodeficiency virus infection ',
#  'cognitive impairment ',
#  'solid tumour cancer ',
#  'pancreatic cancer ',
#  'alzheimer disease ',
#  'constitutional neutropenia ',
#  'neisseria meningitis infection ',
#  'osteoarthritis ',
#  'solid tumour cancer ',
#  'neuropathic pain ',
#  'chronic low back pain ',
#  'pain ',
#  'osteoarthritis ',
#  'cancer related pain ',
#  'fibromyalgia ',
#  'diabetic nephropathy ',
#  'obesity ',
#  'solid tumour cancer ',
#  'acute myeloid leukaemia ',
#  'meningitis ',
#  'syndrome x ',
#  'breast cancer ',
#  'type 2 diabetes ',
#  'hepatitis b virus infection ',
#  'interstitial cystitis ',
#  'inflammation ',
#  'solid tumour cancer ',
#  'bordetella pertussis infection ',
#  'allergy ',
#  'poison intoxication ',
#  'melanoma ',
#  'schizophrenia ',
#  'prostate disease ',
#  'inflammatory bowel disease ',
#  'autoimmune disease ',
#  'systemic lupus erythematosus ',
#  'thrombosis ',
#  'cytomegalovirus infection ',
#  'cardiovascular disease ',
#  'thrombocytopenia ',
#  'pain ',
#  'solid tumour cancer ',
#  'chronic pain ',
#  'crohn disease ',
#  'ulcerative colitis ',
#  'urinary tract infection ',
#  'hypercholesterolaemia ',
#  'pulmonary arterial hypertension ',
#  'multiple myeloma ',
#  'influenza virus infection ',
#  'hypoactive sexual desire dysfunction ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'infectious disease ',
#  'human immunodeficiency virus infection ',
#  'hepatitis ',
#  'hypertension ',
#  'malaria ',
#  'trypanosomiasis ',
#  'infection of p falciparum ',
#  'chronic idiopathic constipation ',
#  'asthma ',
#  'insomnia ',
#  'alzheimer disease ',
#  'dementia ',
#  'overactive bladder ',
#  'alzheimer disease ',
#  'glioblastoma multiforme ',
#  'autoimmune diabetes ',
#  'asthma ',
#  'epilepsy ',
#  'insomnia ',
#  'staphylococcus infection ',
#  'oral cancer ',
#  'multiple myeloma ',
#  'attention deficit hyperactivity disorder ',
#  'hypertension ',
#  'psychotic disorder ',
#  'artery stenosis ',
#  'acute myeloid leukaemia ',
#  'cardiovascular disease ',
#  'solid tumour cancer ',
#  'acne vulgaris ',
#  'hypotension ',
#  'solid tumour cancer ',
#  'non small cell lung cancer ',
#  'gastrointestinal cancer ',
#  'alzheimer disease ',
#  'cerebrovascular ischaemia ',
#  'inflammation ',
#  'sepsis ',
#  'melanoma ',
#  'pharyngitis ',
#  'cell proliferative disorder ',
#  'solid tumour cancer ',
#  'albinism ',
#  'ephelides ',
#  'menkes disease ',
#  'senile lentigines ',
#  'melasma ',
#  'psoriasis vulgaris ',
#  'botulism ',
#  'psychiatric disorder ',
#  'anxiety disorder ',
#  'hypertension ',
#  'alzheimer disease ',
#  'insomnia ',
#  'helicobacter infection ',
#  'anxiety disorder ',
#  'hepatitis c virus infection ',
#  'asthma ',
#  'nerve injury ',
#  'albinism ',
#  'ephelides ',
#  'menkes disease ',
#  'senile lentigines ',
#  'melasma ',
#  'alzheimer disease ',
#  'sepsis ',
#  'congestive heart failure ',
#  'atrial fibrillation ',
#  'solid tumour cancer ',
#  'cough ',
#  'human immunodeficiency virus infection ',
#  'influenza virus infection ',
#  'coxiella infection ',
#  'autoimmune diabetes ',
#  'schizophrenia ',
#  'reperfusion injury ',
#  'myocardial ischemia ',
#  'solid tumour cancer ',
#  'cerebrovascular ischaemia ',
#  'follicular lymphoma ',
#  'malignant rhabdoid tumour ',
#  'brain and central nervous system tumour ',
#  'mesothelioma ',
#  'solid tumour cancer ',
#  'diffuse large b cell lymphoma ',
#  'synovial sarcoma ',
#  'solid tumour cancer ',
#  'asthma ',
#  'hypertension ',
#  'liver cancer ',
#  'anaesthesia ',
#  'pruritus ',
#  'solid tumour cancer ',
#  'chronic pain ',
#  'neuropathic pain ',
#  'thymic cancer ',
#  'ocular hypertension ',
#  'diabetic complication ',
#  'solid tumour cancer ',
#  'hemophilia ',
#  'diabetic complication ',
#  'psychotic disorder ',
#  'mood disorder ',
#  'vomiting ',
#  'neuropathic pain ',
#  'solid tumour cancer ',
#  'cardiovascular disease ',
#  'insomnia ',
#  'human immunodeficiency virus 1 infection ',
#  'multiple myeloma ',
#  'intrahepatic cholangiocarcinoma ',
#  'leishmaniasis ',
#  'visceral leishmaniasis ',
#  'vasomotor allergic rhinitis ',
#  'anthrax ',
#  'rheumatoid arthritis ',
#  'hypertension ',
#  'solid tumour cancer ',
#  'non small cell lung cancer ',
#  'diffuse large b cell lymphoma ',
#  'melanoma ',
#  'leukaemia ',
#  'lymphoma ',
#  'autoimmune diabetes ',
#  'fabry disease ',
#  'pain ',
#  'pruritus ',
#  'solid tumour cancer ',
#  'chronic pain ',
#  'neuropathic pain ',
#  'thymic cancer ',
#  'type 2 diabetes ',
#  'human immunodeficiency virus infection ',
#  'actinic keratosis ',
#  'inflammation ',
#  'burn and burn infection ',
#  'diarrhea ',
#  'parkinson disease ',
#  'diarrhea ',
#  'leukaemia ',
#  'herpes simplex virus infection ',
#  'pain ',
#  'epilepsy ',
#  'bleeding disorder ',
#  'vitamin k deficiency ',
#  'contraception ',
#  'hypertension ',
#  'neuropathic pain ',
#  'type 2 diabetes ',
#  'cytomegalovirus infection ',
#  'solid tumour cancer ',
#  'coronavirus disease 2019 covid 19 ',
#  'type 2 diabetes ',
#  'leukaemia ',
#  'bacterial infection ',
#  'respiratory syncytial virus infection ',
#  'familial adenomatous polyposis ',
#  'excessive daytime sleepiness ',
#  'chronic obstructive pulmonary disease ',
#  'neuropathic pain ',
#  'diabetic complication ',
#  'obesity ',
#  'autoimmune diabetes ',
#  'immune system disease ',
#  'influenza a virus infection ',
#  'keratosis ',
#  'allergic conjunctivitis ',
#  'solid tumour cancer ',
#  'autoimmune diabetes ',
#  'solid tumour cancer ',
#  'familial hypercholesterolemia ',
#  'hypercholesterolaemia ',
#  'irritable bowel syndrome ',
#  'pancreatic cancer ',
#  'solid tumour cancer ',
#  'hepatitis virus infection ',
#  'rosacea ',
#  'melanoma ',
#  'non small cell lung cancer ',
#  'malignant pleural mesothelioma ',
#  'multiple myeloma ',
#  'small cell lung cancer ',
#  'esophageal cancer ',
#  'gastric adenocarcinoma ',
#  'recurrent glioblastoma ',
#  'central nervous system lymphoma ',
#  'diffuse large b cell lymphoma ',
#  'follicular lymphoma ',
#  'prostate cancer ',
#  'ovarian cancer ',
#  'pancreatic cancer ',
#  'triple negative breast cancer ',
#  'chronic myelogenous leukaemia ',
#  'renal cell carcinoma ',
#  'desmoid tumour ',
#  'alzheimer disease ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'alzheimer disease ',
#  'huntington disease ',
#  'stroke ',
#  'type 2 diabetes ',
#  'autoimmune diabetes ',
#  'acute myeloid leukaemia ',
#  'type 2 diabetes ',
#  'neisseria gonorrhoeae infection ',
#  'bacterial infection ',
#  'solid tumour cancer ',
#  'opioid dependence ',
#  'colorectal cancer ',
#  'breast cancer ',
#  'spinal cord injury ',
#  'bladder disease ',
#  'alzheimer disease ',
#  'bipolar disorder ',
#  'hypertension ',
#  'coronavirus disease 2019 covid 19 ',
#  'solid tumour cancer ',
#  'rotavirus infection diarrhoea ',
#  'asthma ',
#  'rheumatoid arthritis ',
#  'neurological disorder ',
#  'type 1 diabetes ',
#  'insulin dependent diabetes ',
#  'bacterial infection ',
#  'nasal congestion ',
#  'human immunodeficiency virus 1 infection ',
#  'pseudomonas infection ',
#  'leukaemia ',
#  'renal cell carcinoma ',
#  'hypercalcaemia ',
#  'anemia ',
#  'motor neurone disease ',
#  'hairy cell leukaemia ',
#  'haematological malignancy ',
#  'dermatomycosis ',
#  'breast cancer ',
#  'multiple sclerosis ',
#  'infectious disease ',
#  'pancreatic cancer ',
#  'osteopetrosis ',
#  'transplant rejection ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'bacterial infection ',
#  'hyperlipidaemia ',
#  'influenza virus infection ',
#  'staphylococcus infection ',
#  'growth hormone deficiency ',
#  'lung cancer ',
#  'major depressive disorder ',
#  'urolithiasis ',
#  'pain ',
#  'peripheral vascular disease ',
#  'angina pectoris ',
#  'autoimmune diabetes ',
#  'solid tumour cancer ',
#  'autoimmune diabetes ',
#  'allergic rhinitis ',
#  'lipid metabolism disorder ',
#  'breast cancer ',
#  'solid tumour cancer ',
#  'pancreatic cancer ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'friedreich s ataxia ',
#  'anxiety disorder ',
#  'solid tumour cancer ',
#  'epilepsy ',
#  'liver cancer ',
#  'multiple sclerosis ',
#  'autoimmune diabetes ',
#  'pain ',
#  'influenza virus infection ',
#  'schizophrenia ',
#  'multiple sclerosis ',
#  'crohn disease ',
#  'bleeding disorder ',
#  'pneumonia ',
#  'rheumatoid arthritis ',
#  'open angle glaucoma ',
#  'ventilator associated pneumonia ',
#  'colorectal cancer ',
#  'fallopian tube cancer ',
#  'metastatic colorectal cancer ',
#  'ovarian cancer ',
#  'peritoneal cavity cancer ',
#  'major depressive disorder ',
#  'blood forming organ disorder ',
#  'urinary incontinence ',
#  'substance use disorder ',
#  'breast cancer ',
#  'solid tumour cancer ',
#  'arteriosclerosis ',
#  'diabetic complication ',
#  'ocular infection ',
#  'hypertension ',
#  'chronic obstructive pulmonary disease ',
#  'immune system disease ',
#  'acute lymphoblastic leukaemia ',
#  'multiple sclerosis ',
#  'acute myeloid lymphoma ',
#  'acute lymphoblastic leukaemia ',
#  'cachexia ',
#  'atopic dermatitis ',
#  'breast cancer ',
#  'solid tumour cancer ',
#  'chronic lymphocytic leukaemia ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'human immunodeficiency virus infection ',
#  'discovery agent ',
#  'multiple sclerosis ',
#  'pancreatic cancer ',
#  'allergy ',
#  'contraception ',
#  'solid tumour cancer ',
#  'colorectal cancer ',
#  'alzheimer disease ',
#  'hepatitis virus infection ',
#  'albinism ',
#  'ephelides ',
#  'menkes disease ',
#  'senile lentigines ',
#  'melasma ',
#  'arteriosclerosis ',
#  'sarcoma ',
#  'schizophrenia ',
#  'glaucoma ocular hypertension ',
#  'human immunodeficiency virus infection ',
#  'severe acute respiratory syndrome sars ',
#  'middle east respiratory syndrome mers ',
#  'attention deficit hyperactivity disorder ',
#  'inflammatory bowel disease ',
#  'allergic conjunctivitis ',
#  'inflammation ',
#  'coronavirus disease 2019 covid 19 ',
#  'inflammation ',
#  'influenza virus infection ',
#  'solid tumour cancer ',
#  'asthma ',
#  'solid tumour cancer ',
#  'colorectal cancer ',
#  'gastric adenocarcinoma ',
#  'pancreatic cancer ',
#  'peritoneal metastasis ',
#  'cognitive impairment ',
#  'dry cough ',
#  'ovarian cancer ',
#  'allergy ',
#  'diabetic neuropathy ',
#  'solid tumour cancer ',
#  'schizophrenia ',
#  'parkinson disease ',
#  'lymphoma ',
#  'methicillin resistant staphylococci infection ',
#  'crohn disease ',
#  'ulcerative colitis ',
#  'urinary tract infection ',
#  'stomach ulcer ',
#  'alzheimer disease ',
#  'leukaemia ',
#  'solid tumour cancer ',
#  'type 1 2 diabetes ',
#  'solid tumour cancer ',
#  'angina pectoris ',
#  'asthma ',
#  'allergy ',
#  'arteriosclerosis ',
#  'ulcerative colitis ',
#  'gastrointestinal disease ',
#  'bacterial infection ',
#  'osteoarthritis pain ',
#  'cancer related pain ',
#  'neuropathic pain ',
#  'inflammatory pain ',
#  'lung cancer ',
#  'non small cell lung cancer ',
#  'pancreatic cancer ',
#  'pain ',
#  'major depressive disorder ',
#  'worm infection ',
#  'solid tumour cancer ',
#  'heart arrhythmia ',
#  'ileus ',
#  'harmful effects of drugs medicaments or biological substances ',
#  'arteriosclerosis ',
#  'respiratory disease ',
#  'cardiac disease ',
#  'hypertension ',
#  'solid tumour cancer ',
#  'premature labour ',
#  'psoriasis vulgaris ',
#  'chronic lymphocytic leukaemia ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'discovery agent ',
#  'hypertension ',
#  'candidiasis ',
#  'solid tumour cancer ',
#  'metastatic cancer ',
#  'pulmonary disease ',
#  'non insulin dependent diabetes ',
#  'multiple myeloma ',
#  'liposarcoma ',
#  'neuroendocrine cancer ',
#  'solid tumour cancer ',
#  'diffuse large b cell lymphoma ',
#  'acute myeloid leukaemia ',
#  'recurrent glioblastoma ',
#  'thrombosis ',
#  'diabetic complication ',
#  'anaemia ',
#  'non insulin dependent diabetes ',
#  'inflammatory bowel disease ',
#  'rheumatoid arthritis ',
#  'albinism ',
#  'ephelides ',
#  'menkes disease ',
#  'senile lentigines ',
#  'melasma ',
#  'dysmenorrhea ',
#  'tobacco dependence ',
#  'neuropathic pain ',
#  'hypertension ',
#  'acromegaly ',
#  'asthma ',
#  'bone marrow transplantation ',
#  'lung infection ',
#  'hepatitis c virus infection ',
#  'neutropenia ',
#  'cerebrovascular ischaemia ',
#  'cough ',
#  'inflammation ',
#  'kidney injury ',
#  'myeloproliferative syndrome ',
#  'asthma ',
#  'lymphoma ',
#  'alzheimer disease ',
#  'osteoporosis ',
#  'female sexual arousal dysfunction ',
#  'lung cancer ',
#  'brain cancer ',
#  'metastatic malignant neoplasm ',
#  'asthma ',
#  'poison intoxication ',
#  'cerebrovascular ischaemia ',
#  'pruritus ',
#  'solid tumour cancer ',
#  'chronic pain ',
#  'neuropathic pain ',
#  'thymic cancer ',
#  'asthma ',
#  'hypertension ',
#  'hyperthyroidism ',
#  'obesity ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'metastatic cancer ',
#  'bacterial infection ',
#  'long chain fatty acid oxidation disorder ',
#  'genetic epileptic syndromes with variable age of onset ',
#  'human immunodeficiency virus infection ',
#  'solid tumour cancer ',
#  'human immunodeficiency virus infection ',
#  'solid tumour cancer ',
#  'schizophrenia ',
#  'leukaemia ',
#  'hypertension ',
#  'serious infection ',
#  'acute lymphoblastic leukaemia ',
#  'bacterial infection ',
#  'lysosomal storage disease ',
#  'migraine ',
#  'depression ',
#  'anaesthesia ',
#  'myelofibrosis ',
#  'infectious disease ',
#  'hypertension ',
#  'psychomotor agitation ',
#  'amyotrophic lateral sclerosis ',
#  'basal cell carcinoma ',
#  'cutaneous t cell lymphoma ',
#  'colorectal cancer ',
#  'ovarian cancer ',
#  'melanoma ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'advanced malignancy ',
#  'cerebrovascular ischaemia ',
#  'genetic disease ',
#  'autoimmune diabetes ',
#  'urinary tract infection ',
#  'bronchitis ',
#  'congestive heart failure ',
#  'edema ',
#  'hypertension ',
#  'paget s disease ',
#  'overactive bladder ',
#  'human immunodeficiency virus infection ',
#  'solid tumour cancer ',
#  'type 1 diabetes ',
#  'chronic obstructive pulmonary disease ',
#  'chronic lymphocytic leukaemia ',
#  'influenza virus infection ',
#  'osteoporosis ',
#  'solid tumour cancer ',
#  'brain injury ',
#  'histoplasma infection ',
#  'hypertension ',
#  'rheumatoid arthritis ',
#  'plaque psoriasis ',
#  'acute myeloid leukaemia ',
#  'ovarian cancer ',
#  'asthma ',
#  'hypertension ',
#  'cystic fibrosis ',
#  'hepatitis b virus infection ',
#  'urinary tract infection ',
#  'autoimmune diabetes ',
#  'igg4 related disease ',
#  'systemic lupus erythematosus ',
#  'rheumatoid arthritis ',
#  'metastatic biliary tract neoplasms ',
#  'breast cancer ',
#  'spinal muscular atrophy ',
#  'pancreatic cancer ',
#  'bone metastases ',
#  'allergic rhinitis ',
#  'bacterial infection ',
#  'solid tumour cancer ',
#  'osteoarthritis pain ',
#  'cancer related pain ',
#  'neuropathic pain ',
#  'inflammatory pain ',
#  'idiopathic thrombocytopenic purpura ',
#  'gastrointestinal disease ',
#  'atopic dermatitis ',
#  'fibrosis ',
#  'huntington disease ',
#  'bacterial infection ',
#  'osteoarthritis pain ',
#  'cancer related pain ',
#  'neuropathic pain ',
#  'inflammatory pain ',
#  'obesity ',
#  'asthma ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'thrombocytopenia ',
#  'hepatitis c virus infection ',
#  'inflammation ',
#  'atrial fibrillation ',
#  'solid tumour cancer ',
#  'inflammatory bowel disease ',
#  'lleum inflammation ',
#  'insomnia ',
#  'solid tumour cancer ',
#  'insomnia ',
#  'cocaine addiction ',
#  'multiple myeloma ',
#  'ovarian cancer ',
#  'pain ',
#  'tourette syndrome ',
#  'neurological disorder ',
#  'coronavirus disease 2019 covid 19 ',
#  'chronic lymphocytic leukaemia ',
#  'solid tumour cancer ',
#  'weight gain ',
#  'solid tumour cancer ',
#  'thrombocytopenia ',
#  'idiopathic thrombocytopenic purpura ',
#  'colorectal cancer ',
#  'metastatic colorectal cancer ',
#  'chronic obstructive pulmonary disease ',
#  'motor neurone disease ',
#  'asthma ',
#  'neoplasm ',
#  'angiogenesis disorder ',
#  'acute lymphoblastic leukaemia ',
#  'type 2 diabetes ',
#  'solid tumour cancer ',
#  'breast cancer ',
#  'hypertension ',
#  'glaucoma ocular hypertension ',
#  'immune system disease ',
#  'cervical intraepithelial neoplasia ',
#  'dysplasia ',
#  'human papillomavirus infection ',
#  'vulvar squamous intraepithelial lesion ',
#  'vulvar intraepithelial neoplasia ',
#  'autoimmune diabetes ',
#  'hypertension ',
#  'bacterial infection ',
#  'pain ',
#  'toxicity ',
#  'hypotension ',
#  'lymphoma ',
#  'rheumatoid arthritis ',
#  'schizophrenia ',
#  'depression ',
#  'anxiety disorder ',
#  'type 2 diabetes ',
#  'vomiting ',
#  'solid tumour cancer ',
#  'bacterial infection ',
#  'acute respiratory distress syndrome ',
#  'myocardial reperfusion injury ',
#  'sepsis ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'pain ',
#  'metastatic melanoma ',
#  'severe acute respiratory syndrome sars ',
#  'middle east respiratory syndrome mers ',
#  'acute lymphocytic leukaemia ',
#  'acute lymphoblastic leukaemia ',
#  'asthma ',
#  'osteoarthritis pain ',
#  'cancer related pain ',
#  'neuropathic pain ',
#  'inflammatory pain ',
#  'liver cancer ',
#  'chronic renal failure ',
#  'cocaine addiction ',
#  'hepatitis c virus infection ',
#  'cerebral infarction ',
#  'huntington disease ',
#  'ischemia reperfusion injury ',
#  'influenza virus infection ',
#  'inflammatory bowel disease ',
#  'ulcerative colitis ',
#  'chronic obstructive pulmonary disease ',
#  'solid tumour cancer ',
#  'diabetic neuropathy ',
#  'diabetic neuropathy ',
#  'melanoma ',
#  'hyperlipidaemia ',
#  'psychotic disorder ',
#  'anxiety disorder ',
#  'major depressive disorder ',
#  'arteriosclerosis ',
#  'arthritis ',
#  'diagnostic imaging ',
#  'hepatitis c virus infection ',
#  'mycobacterium infection ',
#  'solid tumour cancer ',
#  'gram positive bacterial infection ',
#  'diabetic complication ',
#  'renal cell carcinoma ',
#  'albinism ',
#  'ephelides ',
#  'menkes disease ',
#  'senile lentigines ',
#  'melasma ',
#  'acute myeloid leukaemia ',
#  'arteriosclerosis ',
#  'leukaemia ',
#  'mood disorder ',
#  'growth hormone deficiency ',
#  'coronavirus disease 2019 covid 19 ',
#  'short bowel syndrome ',
#  'inflammation ',
#  'crohn disease ',
#  'ulcerative colitis ',
#  'urinary tract infection ',
#  'hepatitis c virus infection ',
#  'thrombosis ',
#  'solid tumour cancer ',
#  'acquired immune deficiency syndrome ',
#  'autoimmune diabetes ',
#  'psoriasis vulgaris ',
#  'fungal infection ',
#  'nausea ',
#  'ovulation dysfunction ',
#  'chronic lymphocytic leukaemia ',
#  'cognitive impairment ',
#  'pain ',
#  'coronavirus disease 2019 covid 19 ',
#  'bacterial infection ',
#  'diabetic complication ',
#  'virus infection ',
#  'pain ',
#  'crohn disease ',
#  'ulcerative colitis ',
#  'urinary tract infection ',
#  'alzheimer disease ',
#  'neuropathic pain ',
#  'osteoarthritis ',
#  'bladder cancer ',
#  'solid tumour cancer ',
#  'mood disorder ',
#  'muscle wasting disease ',
#  'trypanosomiasis ',
#  'hypertension ',
#  'solid tumour cancer ',
#  'acute myeloid leukaemia ',
#  'hepatitis c virus infection ',
#  'inflammatory bowel disease ',
#  'angina pectoris ',
#  'chronic pain ',
#  'fear related disorder ',
#  'hypertension ',
#  'immune system disease ',
#  'type 2 diabetes ',
#  'bordetella pertussis infection ',
#  'schizophrenia ',
#  'blood transfusion ',
#  'solid tumour cancer ',
#  'bacterial infection ',
#  'metastatic melanoma ',
#  'solid tumour cancer ',
#  'intractable insomnia ',
#  'solid tumour cancer ',
#  'muscle wasting disease ',
#  'cervical cancer ',
#  'oropharyngeal cancer ',
#  'human immunodeficiency virus infection ',
#  'chronic obstructive pulmonary disease ',
#  'hepatocellular carcinoma ',
#  'glioblastoma multiforme ',
#  'adrenoleukodystrophy ',
#  'motor neurone disease ',
#  'glaucoma ocular hypertension ',
#  'cardiovascular disease ',
#  'solid tumour cancer ',
#  'non small cell lung cancer ',
#  'melanoma ',
#  'merkel cell carcinoma ',
#  'renal cell carcinoma ',
#  'cytomegalovirus infection ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'chronic myelogenous leukaemia ',
#  'immune system disease ',
#  'acute and chronic heart failure ',
#  'solid tumour cancer ',
#  'metastatic cancer ',
#  'bipolar disorder ',
#  'nausea and vomiting ',
#  'diabetic complication ',
#  'type 2 diabetes ',
#  'alzheimer disease ',
#  'multiple sclerosis ',
#  'sjogren syndrome ',
#  'helicobacter infection ',
#  'solid tumour cancer ',
#  'obesity ',
#  'female sexual arousal dysfunction ',
#  'constipation ',
#  'yellow fever virus infection ',
#  'type 2 diabetes ',
#  'multiple sclerosis ',
#  'crohn disease ',
#  'restless legs syndrome ',
#  'leber congenital amaurosis ',
#  'retinitis pigmentosa ',
#  'corneal disease ',
#  'skin disease ',
#  'muscular wasting ',
#  'acromegaly ',
#  'respiratory tract inflammation ',
#  'hepatitis c virus infection ',
#  'diabetic complication ',
#  'hypertension ',
#  'sleep wake disorder ',
#  'rhinitis ',
#  'chronic hcv 1 infection ',
#  'dengue fever ',
#  'obesity ',
#  'cognitive impairment ',
#  'solid tumour cancer ',
#  'aspergillosis ',
#  'typhoid fever ',
#  'inflammation ',
#  'otitis externa ',
#  'hepatitis c virus infection ',
#  'carcinoid syndrome ',
#  'ocular inflammation ',
#  'heart disease ',
#  'diabetic retinopathy ',
#  'disuse muscle atrophy ',
#  'gastrointestinal disease ',
#  'factor ix deficiency ',
#  'nicotine dependence ',
#  'solid tumour cancer ',
#  'solid tumour cancer ',
#  'non small cell lung cancer ',
#  'asthma ',
#  'recurrent glioblastoma ',
#  'hepatocellular carcinoma ',
#  'hypertension ',
#  'human immunodeficiency virus infection ',
#  'solid tumour cancer ',
#  'nerve injury ',
#  'solid tumour cancer ',
#  'alzheimer disease ',
#  'anxiety disorder ',
#  'heart failure ',
#  'diabetic nephropathy ',
#  'microvascular angina ',
#  'muscle atrophy ',
#  'alopecia ',
#  'rheumatoid arthritis ',
#  'coronavirus disease 2019 covid 19 ',
#  'asthma ',
#  'thrombosis ',
#  'coronavirus disease 2019 covid 19 ',
#  'reperfusion injury ',
#  'pain ',
#  'diffuse large b cell lymphoma ',
#  'non hodgkin lymphoma ',
#  'gastric adenocarcinoma ',
#  'deep vein thrombosis ',
#  'virus infection ',
#  'anxiety disorder ',
#  'hepatic fibrosis ',
#  'lymphoma ',
#  'solid tumour cancer ',
#  'leukaemia ',
#  'depression ',
#  'vibrio cholerae infection ',
#  'bacterial infection ',
#  'non small cell lung cancer ',
#  'factor viii deficiency ',
#  'multiple myeloma ',
#  'small cell lung cancer ',
#  'solid tumour cancer ',
#  'acne vulgaris ',
#  'friedreich s ataxia ',
#  'radiographic contrast medium ',
#  'solid tumour cancer ',
#  'pain ',
#  'fibromyalgia ',
#  'breast cancer ',
#  'solid tumour cancer ',
#  'schizophrenia ',
#  'angina pectoris ',
#  'cardiovascular disease ',
#  'advanced solid tumour ',
#  'major depressive disorder ',
#  'leukodystrophy ',
#  'hypertension ',
#  'fibrosis ',
#  'fungal infection ',
#  'solid tumour cancer ',
#  'lung disease ',
#  'diabetic nephropathy ',
#  'hepatitis c virus infection ',
#  'bleeding disorder ',
#  'solid tumour cancer ',
#  'coronary artery disease ',
#  'myocardial infarction ',
#  'solid tumour cancer ',
#  'schizoaffective disorder ',
#  'schizophrenia ',
#  'gastric motility disorder ',
#  'chemotherapy induced nausea ',
#  'irritable bowel syndrome ',
#  'uterine fibroids ',
#  'thrombosis ',
#  'solid tumour cancer ',
#  'schizophrenia ',
#  'solid tumour cancer ',
#  'pain ',
#  'solid tumour cancer ',
#  'neuropathic pain ',
#  'pancreatic cancer ',
#  'postpartum depression ',
#  'depression ',
#  'status epilepticus seizure ',
#  'essential tremor or related tremors ',
#  'congestive heart failure ',
#  'coeliac disease ',
#  ...]

# %%
df['Name'] = modified

# %%
df['Name'] = df['Name'].str.strip()
matched['Name'] = matched['Name'].str.strip()
# Out:
# C:\Users\rzwart\AppData\Local\Temp\ipykernel_19272\140104363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched['Name'] = matched['Name'].str.strip()

# %%
final = pd.merge(df, matched, on = 'Name', how = 'left')

# %%
final
# Out:
#       DRUG_ID     DRUG_NAME                                   DISEASES  \
# 0      D00ABE       ALD-301                                  Ischemia
# 1      D00ABE       ALD-301               Peripheral arterial disease
# 2      D00ABO       KW-2449                   Acute myeloid leukaemia
# 3      D00ABW      Opterone                        Hormone deficiency
# 4      D00ACC        ND1251                                Depression
# ...       ...           ...                                        ...
# 29562  DZU72C       OKI 179                       Solid tumour/cancer
# 29563  DZVF15       TRN-110  Attention deficit hyperactivity disorder
# 29564  DZW53X    GSK4069889                Non-small cell lung cancer
# 29565  DZW53X    GSK4069889                Non-small cell lung cancer
# 29566  DZY4R2  JNJ-74699157                       Solid tumour/cancer
#
#                           PHASE                                      Name  \
# 0                       Phase 2                                  ischemia
# 1                       Phase 2               peripheral arterial disease
# 2                       Phase 1                   acute myeloid leukaemia
# 3       Discontinued in Phase 1                        hormone deficiency
# 4       Discontinued in Phase 1                                depression
# ...                         ...                                       ...
# 29562                   Phase 1                       solid tumour cancer
# 29563            Clinical Trial  attention deficit hyperactivity disorder
# 29564                   Phase 2                non small cell lung cancer
# 29565                   Phase 2                non small cell lung cancer
# 29566                   Phase 1                       solid tumour cancer
#
#                                ontologyTermName  \
# 0                                           NaN
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 3                                           NaN
# 4                                  Depressivity
# ...                                         ...
# 29562                                       NaN
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
# 29566                                       NaN
#
#                                  ontologyTermIRI  score validated review  \
# 0                                            NaN    NaN       NaN    NaN
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.0     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.0     False  False
# 3                                            NaN    NaN       NaN    NaN
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.0     False  False
# ...                                          ...    ...       ...    ...
# 29562                                        NaN    NaN       NaN    NaN
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.0     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.0     False  False
# 29566                                        NaN    NaN       NaN    NaN
#
#                ID
# 0             NaN
# 1      HP:0004950
# 2      HP:0004808
# 3             NaN
# 4      HP:0000716
# ...           ...
# 29562         NaN
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
# 29566         NaN
#
# [29567 rows x 11 columns]

# %%
final.to_csv(f'output/drug_to_disease_HP_{DISEASE_PREFIX}.csv', encoding = 'utf-8-sig')

# %% [markdown]
# ### **Comparison**

# %%
final = pd.read_csv(f'output/drug_to_disease_HP_{DISEASE_PREFIX}.csv', header=0)
print(f'There are {len(final)} rows of drug-disease pairs that are attempted to match with disease ID')
# Out:
# There are 29567 rows of drug-disease pairs that are attempted to match with disease ID

# %%
final_filtered = final[final['score'] > 80]
print(f'There are {len(final_filtered)} rows of drug-disease pairs that are suifficiently matched with disease ID')
# Out:
# There are 14760 rows of drug-disease pairs that are suifficiently matched with disease ID

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID                                        DRUG_NAME  \
# 1               1  D00ABE                                          ALD-301
# 2               2  D00ABO                                          KW-2449
# 4               4  D00ACC                                           ND1251
# 5               5  D00ACH                                         HMR-4004
# 11             11  D00AHT  PRAME antigen-specific cancer immunotherapeutic
# ...           ...     ...                                              ...
# 29560       29560  DZTX12                                           ASC-J9
# 29561       29561  DZTX12                                           ASC-J9
# 29563       29563  DZVF15                                          TRN-110
# 29564       29564  DZW53X                                       GSK4069889
# 29565       29565  DZW53X                                       GSK4069889
#
#                                         DISEASES                     PHASE  \
# 1                   Peripheral arterial disease                    Phase 2
# 2                       Acute myeloid leukaemia                    Phase 1
# 4                                    Depression    Discontinued in Phase 1
# 5                           Bacterial infection                 Terminated
# 11                   Non-small-cell lung cancer                    Phase 2
# ...                                          ...                       ...
# 29560                                Thrombosis                    Phase 2
# 29561                   End-stage renal disease                    Phase 2
# 29563  Attention deficit hyperactivity disorder             Clinical Trial
# 29564                Non-small cell lung cancer                    Phase 2
# 29565                Non-small cell lung cancer                    Phase 2
#
#                                            Name  \
# 1                   peripheral arterial disease
# 2                       acute myeloid leukaemia
# 4                                    depression
# 5                           bacterial infection
# 11                   non small cell lung cancer
# ...                                         ...
# 29560                                thrombosis
# 29561                   end stage renal disease
# 29563  attention deficit hyperactivity disorder
# 29564                non small cell lung cancer
# 29565                non small cell lung cancer
#
#                                ontologyTermName  \
# 1                  Peripheral arterial stenosis
# 2                        Acute myeloid leukemia
# 4                                  Depressivity
# 5                                    Cellulitis
# 11                Non-small cell lung carcinoma
# ...                                         ...
# 29560                            Thrombocytosis
# 29561            Stage 5 chronic kidney disease
# 29563  Attention deficit hyperactivity disorder
# 29564             Non-small cell lung carcinoma
# 29565             Non-small cell lung carcinoma
#
#                                  ontologyTermIRI   score validated review  \
# 1      http://purl.obolibrary.org/obo/HP_0004950  100.00     False  False
# 2      http://purl.obolibrary.org/obo/HP_0004808  100.00     False  False
# 4      http://purl.obolibrary.org/obo/HP_0000716  100.00     False  False
# 5      http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 11     http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
# ...                                          ...     ...       ...    ...
# 29560  http://purl.obolibrary.org/obo/HP_0001894   83.33     False  False
# 29561  http://purl.obolibrary.org/obo/HP_0003774  100.00     False  False
# 29563  http://purl.obolibrary.org/obo/HP_0007018  100.00     False  False
# 29564  http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
# 29565  http://purl.obolibrary.org/obo/HP_0030358  100.00     False  False
#
#                ID
# 1      HP:0004950
# 2      HP:0004808
# 4      HP:0000716
# 5      HP:0100658
# 11     HP:0030358
# ...           ...
# 29560  HP:0001894
# 29561  HP:0003774
# 29563  HP:0007018
# 29564  HP:0030358
# 29565  HP:0030358
#
# [14760 rows x 12 columns]

# %%
unique_drugs
# Out:
# ['aclarubicin',
#  'aldosterone',
#  'aminoquinuride',
#  'androstenediol',
#  'androstenedione',
#  'astemizole',
#  'bacitracin',
#  'beclometasone dipropionate',
#  'budesonide',
#  'busulfan',
#  'candesartan cilexetil',
#  'cefonicid',
#  'cefotetan',
#  'cefotiam',
#  'cefuroxime',
#  'cefalotin',
#  'cefradine',
#  'chlorhexidine',
#  'chloropyramine',
#  'chlorpromazine',
#  'clomifene',
#  'clotrimazole',
#  'cortisone acetate',
#  'ciclosporin',
#  'dacarbazine',
#  'danazol',
#  'dasatinib',
#  'daunorubicin',
#  'prasterone',
#  'desogestrel',
#  'desoxycortone',
#  'dexamethasone',
#  'disulfiram',
#  'dobutamine',
#  'docetaxel',
#  'doxorubicin',
#  'doxycycline',
#  'ebastine',
#  'econazole',
#  'entacapone',
#  'erlotinib',
#  'estradiol',
#  'estradiol benzoate',
#  'estriol succinate',
#  'ethinylestradiol',
#  'ethisterone',
#  'etonogestrel',
#  'flopropione',
#  'floxacillin',
#  'fluphenazine',
#  'gefitinib',
#  'gestrinone',
#  'hexachlorophene',
#  'hydrocortisone',
#  'imatinib',
#  'diiodohydroxyquinoline',
#  'lapatinib',
#  'levodopa',
#  'levonorgestrel',
#  'losartan',
#  'medroxyprogesterone',
#  'methyldopa',
#  'miconazole',
#  'mitoxantrone',
#  'montelukast',
#  'nandrolone',
#  'nandrolone decanoate',
#  'nelfinavir',
#  'niclosamide',
#  'nilotinib',
#  'norethisterone',
#  'norethindrone acetate',
#  'perhexiline',
#  'prednisolone',
#  'prednisolone tebutate',
#  'pregnenolone succinate',
#  'progesterone',
#  'raloxifene',
#  'secobarbital',
#  'sorafenib',
#  'sulindac',
#  'suloctidil',
#  'sunitinib',
#  'tacrolimus',
#  'tamoxifen',
#  'terfenadine',
#  'testosterone',
#  'thioridazine',
#  'tiludronic acid',
#  'tolcapone',
#  'ubenimex',
#  'zafirlukast',
#  'zoledronic acid',
#  'bithionol',
#  'estriol',
#  'estrone',
#  'oxyquinoline',
#  'mestanolone',
#  'mesterolone',
#  'methyltestosterone',
#  'pyrithione',
#  'quercetin',
#  'ruboxistaurin',
#  'thiram',
#  'androstanolone',
#  'tirilazad',
#  'ascorbic acid',
#  'pazopanib',
#  'gentian violet',
#  'vandetanib',
#  'crizotinib',
#  'hydroxyprogesterone caproate',
#  'prazosin',
#  'axitinib',
#  'afatinib',
#  'zinc chloride',
#  'bosutinib',
#  'cisplatin',
#  'colistin',
#  'regorafenib',
#  'sodium aurothiomalate',
#  'cabozantinib',
#  'ponatinib',
#  'dimethyl fumarate',
#  'ibrutinib',
#  'ceritinib',
#  'nintedanib',
#  'lenvatinib',
#  'cetuximab',
#  'panitumumab',
#  'siltuximab',
#  'osimertinib',
#  'necitumumab',
#  'chromic chloride',
#  'opicapone',
#  'icotinib',
#  'olmutinib',
#  'midostaurin',
#  'brigatinib',
#  'neratinib',
#  'tivozanib',
#  'dacomitinib',
#  'lorlatinib',
#  'caplacizumab',
#  'quizartinib',
#  'entrectinib',
#  'fedratinib',
#  'selumetinib',
#  'tucatinib',
#  'ripretinib',
#  'pralsetinib',
#  'filgotinib',
#  'infigratinib']

# %%
column_names = ["DRUG_ID", "DRUG_NAME", "DISEASES", 'PHASE']

df = pd.DataFrame(columns = column_names)

df.head(10)
# Out:
# Empty DataFrame
# Columns: [DRUG_ID, DRUG_NAME, DISEASES, PHASE]
# Index: []

# %%
i = 0
for index, row in final_filtered.iterrows(): 
  if row['DRUG_NAME'].lower() not in unique_drugs or row['ID'] not in unique_dis_id:
    final_filtered = final_filtered.drop(labels = index, axis = 0)
   
len(final_filtered)
# Out:
# 29

# %%
for index, row in final_filtered.iterrows(): 
  drug = row['DRUG_NAME'].lower()
  id_value = graph_drugs[graph_drugs['DRUG_NAME'] == drug]['STRUCT_ID'].values[0]
  final_filtered.at[index, 'DRUG_ID'] = id_value
len(final_filtered)
# Out:
# 29

# %%
final_filtered
# Out:
#        Unnamed: 0 DRUG_ID        DRUG_NAME                        DISEASES  \
# 878           878    1932        Nilotinib  Chronic myelogenous leukaemia
# 1167         1167    1879       Nandrolone                   Osteoporosis
# 1291         1291     542        Cefonicid            Bacterial infection
# 1945         1945     574        Cefalotin            Bacterial infection
# 2262         2262    2351       Raloxifene                   Osteoporosis
# 5006         5006    4138   Gentian violet            Bacterial infection
# 7442         7442     576        Cefradine            Bacterial infection
# 8028         8028    2607     Testosterone                   Osteoporosis
# 8752         8752    4977       Siltuximab                         Anemia
# 9195         9195     960      Doxorubicin                         Tumour
# 12293       12293     547        Cefotetan            Bacterial infection
# 12354       12354    1423         Imatinib  Chronic myelogenous leukaemia
# 12748       12748    1762       Methyldopa                   Hypertension
# 13499       13499     700        Clomifene             Female infertility
# 13982       13982    1610         Losartan                   Hypertension
# 14470       14470     785        Dasatinib  Chronic myelogenous leukaemia
# 16688       16688     111      Aldosterone                   Hypertension
# 16693       16693     785        Dasatinib      Chronic myeloid leukaemia
# 17544       17544     937       Dobutamine                  Heart failure
# 18177       18177    3514        Quercetin                        Obesity
# 18307       18307    1423         Imatinib      Chronic myeloid leukaemia
# 18385       18385    1388   Hydrocortisone                   Inflammation
# 19096       19096     281       Bacitracin                 Skin infection
# 20415       20415    1610         Losartan                   Hypertension
# 21875       21875    2666  Tiludronic acid                   Osteoporosis
# 24637       24637     597    Chlorhexidine            Bacterial infection
# 25658       25658    4209         Prazosin       Congestive heart failure
# 25660       25660    4209         Prazosin                   Hypertension
# 27493       27493    1364  Hexachlorophene            Bacterial infection
#
#                 PHASE                           Name  \
# 878          Approved  chronic myelogenous leukaemia
# 1167         Approved                   osteoporosis
# 1291         Approved            bacterial infection
# 1945         Approved            bacterial infection
# 2262         Approved                   osteoporosis
# 5006         Approved            bacterial infection
# 7442         Approved            bacterial infection
# 8028         Approved                   osteoporosis
# 8752         Approved                         anemia
# 9195    Investigative                         tumour
# 12293        Approved            bacterial infection
# 12354        Approved  chronic myelogenous leukaemia
# 12748        Approved                   hypertension
# 13499        Approved             female infertility
# 13982        Approved                   hypertension
# 14470        Approved  chronic myelogenous leukaemia
# 16688        Approved                   hypertension
# 16693        Approved      chronic myeloid leukaemia
# 17544        Approved                  heart failure
# 18177        Approved                        obesity
# 18307        Approved      chronic myeloid leukaemia
# 18385        Approved                   inflammation
# 19096        Approved                 skin infection
# 20415        Approved                   hypertension
# 21875        Approved                   osteoporosis
# 24637        Approved            bacterial infection
# 25658        Approved       congestive heart failure
# 25660        Approved                   hypertension
# 27493        Approved            bacterial infection
#
#                     ontologyTermName  \
# 878     Chronic myelogenous leukemia
# 1167                    Osteoporosis
# 1291                      Cellulitis
# 1945                      Cellulitis
# 2262                    Osteoporosis
# 5006                      Cellulitis
# 7442                      Cellulitis
# 8028                    Osteoporosis
# 8752                          Anemia
# 9195                        Neoplasm
# 12293                     Cellulitis
# 12354   Chronic myelogenous leukemia
# 12748                   Hypertension
# 13499             Female infertility
# 13982                   Hypertension
# 14470   Chronic myelogenous leukemia
# 16688                   Hypertension
# 16693   Chronic myelogenous leukemia
# 17544       Congestive heart failure
# 18177                        Obesity
# 18307   Chronic myelogenous leukemia
# 18385  Gastrointestinal inflammation
# 19096                     Cellulitis
# 20415                   Hypertension
# 21875                   Osteoporosis
# 24637                     Cellulitis
# 25658       Congestive heart failure
# 25660                   Hypertension
# 27493                     Cellulitis
#
#                                  ontologyTermIRI   score validated review  \
# 878    http://purl.obolibrary.org/obo/HP_0005506  100.00     False  False
# 1167   http://purl.obolibrary.org/obo/HP_0000939  100.00     False  False
# 1291   http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 1945   http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 2262   http://purl.obolibrary.org/obo/HP_0000939  100.00     False  False
# 5006   http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 7442   http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 8028   http://purl.obolibrary.org/obo/HP_0000939  100.00     False  False
# 8752   http://purl.obolibrary.org/obo/HP_0001903  100.00     False  False
# 9195   http://purl.obolibrary.org/obo/HP_0002664  100.00     False  False
# 12293  http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 12354  http://purl.obolibrary.org/obo/HP_0005506  100.00     False  False
# 12748  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 13499  http://purl.obolibrary.org/obo/HP_0008222  100.00     False  False
# 13982  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 14470  http://purl.obolibrary.org/obo/HP_0005506  100.00     False  False
# 16688  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 16693  http://purl.obolibrary.org/obo/HP_0005506   94.12     False  False
# 17544  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 18177  http://purl.obolibrary.org/obo/HP_0001513  100.00     False  False
# 18307  http://purl.obolibrary.org/obo/HP_0005506   94.12     False  False
# 18385  http://purl.obolibrary.org/obo/HP_0004386   84.21     False  False
# 19096  http://purl.obolibrary.org/obo/HP_0100658  100.00     False  False
# 20415  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 21875  http://purl.obolibrary.org/obo/HP_0000939  100.00     False  False
# 24637  http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
# 25658  http://purl.obolibrary.org/obo/HP_0001635  100.00     False  False
# 25660  http://purl.obolibrary.org/obo/HP_0000822  100.00     False  False
# 27493  http://purl.obolibrary.org/obo/HP_0100658   85.71     False  False
#
#                ID
# 878    HP:0005506
# 1167   HP:0000939
# 1291   HP:0100658
# 1945   HP:0100658
# 2262   HP:0000939
# 5006   HP:0100658
# 7442   HP:0100658
# 8028   HP:0000939
# 8752   HP:0001903
# 9195   HP:0002664
# 12293  HP:0100658
# 12354  HP:0005506
# 12748  HP:0000822
# 13499  HP:0008222
# 13982  HP:0000822
# 14470  HP:0005506
# 16688  HP:0000822
# 16693  HP:0005506
# 17544  HP:0001635
# 18177  HP:0001513
# 18307  HP:0005506
# 18385  HP:0004386
# 19096  HP:0100658
# 20415  HP:0000822
# 21875  HP:0000939
# 24637  HP:0100658
# 25658  HP:0001635
# 25660  HP:0000822
# 27493  HP:0100658

# %%
final_filtered = final_filtered.drop(labels = ['Unnamed: 0', 'score'], axis =1)

# %%
final_filtered.head(10)
# Out:
#      DRUG_ID       DRUG_NAME                        DISEASES           PHASE  \
# 878     1932       Nilotinib  Chronic myelogenous leukaemia         Approved
# 1167    1879      Nandrolone                   Osteoporosis         Approved
# 1291     542       Cefonicid            Bacterial infection         Approved
# 1945     574       Cefalotin            Bacterial infection         Approved
# 2262    2351      Raloxifene                   Osteoporosis         Approved
# 5006    4138  Gentian violet            Bacterial infection         Approved
# 7442     576       Cefradine            Bacterial infection         Approved
# 8028    2607    Testosterone                   Osteoporosis         Approved
# 8752    4977      Siltuximab                         Anemia         Approved
# 9195     960     Doxorubicin                         Tumour    Investigative
#
#                                Name              ontologyTermName  \
# 878   chronic myelogenous leukaemia  Chronic myelogenous leukemia
# 1167                   osteoporosis                  Osteoporosis
# 1291            bacterial infection                    Cellulitis
# 1945            bacterial infection                    Cellulitis
# 2262                   osteoporosis                  Osteoporosis
# 5006            bacterial infection                    Cellulitis
# 7442            bacterial infection                    Cellulitis
# 8028                   osteoporosis                  Osteoporosis
# 8752                         anemia                        Anemia
# 9195                         tumour                      Neoplasm
#
#                                 ontologyTermIRI validated review          ID
# 878   http://purl.obolibrary.org/obo/HP_0005506     False  False  HP:0005506
# 1167  http://purl.obolibrary.org/obo/HP_0000939     False  False  HP:0000939
# 1291  http://purl.obolibrary.org/obo/HP_0100658     False  False  HP:0100658
# 1945  http://purl.obolibrary.org/obo/HP_0100658     False  False  HP:0100658
# 2262  http://purl.obolibrary.org/obo/HP_0000939     False  False  HP:0000939
# 5006  http://purl.obolibrary.org/obo/HP_0100658     False  False  HP:0100658
# 7442  http://purl.obolibrary.org/obo/HP_0100658     False  False  HP:0100658
# 8028  http://purl.obolibrary.org/obo/HP_0000939     False  False  HP:0000939
# 8752  http://purl.obolibrary.org/obo/HP_0001903     False  False  HP:0001903
# 9195  http://purl.obolibrary.org/obo/HP_0002664     False  False  HP:0002664

# %%
final_filtered.to_csv(f'output/matched_drug_to_disease_{DISEASE_PREFIX}.csv', encoding = 'utf-8-sig')
